# %%
import pandas as pd # for data wrangling purpose
import numpy as np # Basic computation library
import seaborn as sns # For Visualization 
import matplotlib.pyplot as plt # ploting package
# %matplotlib inline
import warnings # Filtering warnings
warnings.filterwarnings('ignore')

# %%
CI=pd.read_csv('Census income.csv')

# %%
print('No of Rows:',CI.shape[0])
print('No of Columns:',CI.shape[1])
CI.head()
# Out:
# No of Rows: 32560
# No of Columns: 15
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States   <=50K
# 1             0             0              40   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40            Cuba   <=50K
# 4             0             0              40   United-States   <=50K

# %%
CI.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %% [markdown]
# Data Integrity Check

# %%
CI.duplicated().sum()
# Out:
# 24

# %%
CI.isin([' ?']).sum()
# Out:
# Age                  0
# Workclass         1836
# Fnlwgt               0
# Education            0
# Education_num        0
# Marital_status       0
# Occupation        1843
# Relationship         0
# Race                 0
# Sex                  0
# Capital_gain         0
# Capital_loss         0
# Hours_per_week       0
# Native_country     583
# Income               0
# dtype: int64

# %%
CI=CI.replace(' ?',np.NaN)

# %%
CI.isin([' ','NA','-']).sum().any()
# Out:
# False

# %% [markdown]
# Let drop duplicated entry from dataset before checking null values.

# %%
CI.drop_duplicates(keep='last', inplace=True)

# %% [markdown]
# Missing value check

# %%
plt.figure(figsize=(10,6))
sns.heatmap(CI.isnull())
# Out:
# <AxesSubplot:>

# %%
#Finding what percentage of data is missing from the dataset
missing_values = CI.isnull().sum().sort_values(ascending = False)
percentage_missing_values =(missing_values/len(CI))*100
print(pd.concat([missing_values, percentage_missing_values], axis =1, keys =['Missing Values', '% Missing data']))
# Out:
#                 Missing Values  % Missing data
# Occupation                1843        5.664495
# Workclass                 1836        5.642980
# Native_country             582        1.788788
# Age                          0        0.000000
# Fnlwgt                       0        0.000000
# Education                    0        0.000000
# Education_num                0        0.000000
# Marital_status               0        0.000000
# Relationship                 0        0.000000
# Race                         0        0.000000
# Sex                          0        0.000000
# Capital_gain                 0        0.000000
# Capital_loss                 0        0.000000
# Hours_per_week               0        0.000000
# Income                       0        0.000000

# %%
# Separating numerical and categorical variable
Numerical=['Age','Fnlwgt','Education_num','Capital_gain','Capital_loss','Hours_per_week']
Category=['Workclass','Education','Marital_status','Occupation','Relationship','Race','Sex','Native_country','Income']

# %% [markdown]
# # Missing value imputation

# %%
# Imputating Missing value with mode for categorical features
CI['Occupation'].fillna(CI['Occupation'].mode()[0],inplace=True)
CI['Workclass'].fillna(CI['Workclass'].mode()[0],inplace=True)
CI['Native_country'].fillna(CI['Native_country'].mode()[0],inplace=True)

# %% [markdown]
# Missing Value Check After Imputataion

# %%
#Finding what percentage of data is missing from the dataset
missing_values = CI.isnull().sum().sort_values(ascending = False)
percentage_missing_values =(missing_values/len(CI))*100
print(pd.concat([missing_values, percentage_missing_values], axis =1, keys =['Missing Values', '% Missing data']))
# Out:
#                 Missing Values  % Missing data
# Age                          0             0.0
# Workclass                    0             0.0
# Fnlwgt                       0             0.0
# Education                    0             0.0
# Education_num                0             0.0
# Marital_status               0             0.0
# Occupation                   0             0.0
# Relationship                 0             0.0
# Race                         0             0.0
# Sex                          0             0.0
# Capital_gain                 0             0.0
# Capital_loss                 0             0.0
# Hours_per_week               0             0.0
# Native_country               0             0.0
# Income                       0             0.0

# %% [markdown]
# Statistical Matrix

# %%
# Visualizing the statistics of the columns using heatmap.
plt.figure(figsize=(12,8))
sns.heatmap(CI.describe(),linewidths = 0.1,fmt='0.1f',annot = True,cmap='PiYG')
# Out:
# <AxesSubplot:>

# %%
CI.describe().T
# Out:
#                   count           mean            std      min       25%  \
# Age             32536.0      38.585536      13.638193     17.0      28.0
# Fnlwgt          32536.0  189784.298992  105556.258211  12285.0  117831.5
# Education_num   32536.0      10.081725       2.571622      1.0       9.0
# Capital_gain    32536.0    1078.410069    7388.068465      0.0       0.0
# Capital_loss    32536.0      87.370912     403.107737      0.0       0.0
# Hours_per_week  32536.0      40.440343      12.347079      1.0      40.0
#
#                      50%        75%        max
# Age                 37.0      48.00       90.0
# Fnlwgt          178356.0  236993.25  1484705.0
# Education_num       10.0      12.00       16.0
# Capital_gain         0.0       0.00    99999.0
# Capital_loss         0.0       0.00     4356.0
# Hours_per_week      40.0      45.00       99.0

# %%
for i in Category:
    print(i)
    print(CI[i].value_counts())
    print('='*100)
# Out:
# Workclass
#  Private             24509
#  Self-emp-not-inc     2540
#  Local-gov            2093
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64
# ====================================================================================================
# Education
#  HS-grad         10494
#  Some-college     7282
#  Bachelors        5352
#  Masters          1722
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           645
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           332
#  1st-4th           166
#  Preschool          50
# Name: Education, dtype: int64
# ====================================================================================================
# Marital_status
#  Married-civ-spouse       14970
#  Never-married            10666
#  Divorced                  4441
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: Marital_status, dtype: int64
# ====================================================================================================
# Occupation
#  Prof-specialty       5979
#  Craft-repair         4094
#  Exec-managerial      4065
#  Adm-clerical         3767
#  Sales                3650
#  Other-service        3291
#  Machine-op-inspct    2000
#  Transport-moving     1597
#  Handlers-cleaners    1369
#  Farming-fishing       992
#  Tech-support          927
#  Protective-serv       649
#  Priv-house-serv       147
#  Armed-Forces            9
# Name: Occupation, dtype: int64
# ====================================================================================================
# Relationship
#  Husband           13187
#  Not-in-family      8291
#  Own-child          5064
#  Unmarried          3445
#  Wife               1568
#  Other-relative      981
# Name: Relationship, dtype: int64
# ====================================================================================================
# Race
#  White                 27794
#  Black                  3122
#  Asian-Pac-Islander     1038
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: Race, dtype: int64
# ====================================================================================================
# Sex
#  Male      21774
#  Female    10762
# Name: Sex, dtype: int64
# ====================================================================================================
# Native_country
#  United-States                 29734
#  Mexico                          639
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        62
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
#  Nicaragua                        34
#  Peru                             31
#  France                           29
#  Greece                           29
#  Ecuador                          28
#  Ireland                          24
#  Hong                             20
#  Trinadad&Tobago                  19
#  Cambodia                         19
#  Thailand                         18
#  Laos                             18
#  Yugoslavia                       16
#  Outlying-US(Guam-USVI-etc)       14
#  Honduras                         13
#  Hungary                          13
#  Scotland                         12
#  Holand-Netherlands                1
# Name: Native_country, dtype: int64
# ====================================================================================================
# Income
#  <=50K    24697
#  >50K      7839
# Name: Income, dtype: int64
# ====================================================================================================

# %% [markdown]
# # EDA

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('husl')
f,ax=plt.subplots(1,2,figsize=(18,10))
CI['Income'].value_counts().plot.pie(explode=[0,0.1],autopct='%3.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':18}, ax=ax[0],shadow=True)
ax[0].set_title('Population Distribution', fontsize=22,fontweight ='bold')
ax[0].set_ylabel('')
sns.countplot('Income',data=CI,ax=ax[1])
ax[1].set_title('Income Distribution',fontsize=22,fontweight ='bold')
ax[1].set_xlabel("Income",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=18,fontweight ='bold')
plt.show()

# %% [markdown]
# Exploration of Age

# %%
print('Minimum Age:', CI['Age'].min(),'years')
print('Maximum Age:', CI['Age'].max(),'years')
print('Average Age:', CI['Age'].mean(),'years')
# Out:
# Minimum Age: 17 years
# Maximum Age: 90 years
# Average Age: 38.58553602163757 years

# %%
# Defining function to create new columns to classify people according different age gruop
def age_group(x):
    x = int(x)
    x = abs(x)
    if (18 < x < 31):
        return "19-30"
    if (30 < x < 41) :
        return '31-40'
    if (40 < x <51):
        return '41-50'
    if (50 < x < 61):
        return "51-60"
    if (60 < x < 71):
        return "61-70"
    else :
        return 'Greater Than 70'

# %%
# Calling function age_group
CI['age_group']=CI['Age'].apply(age_group)

# %%
plt.figure(figsize=(12,6))
order_list = ['19-30','31-40','41-50','51-60','61-70','Greater Than 70']
p = sns.countplot(CI['age_group'], hue=CI['Income'], palette='hsv', order=order_list)
plt.title('Income of Individuals of Different Age Groups', fontsize=22, fontweight='bold')
p.set_xlabel('Age Groups')
plt.xticks(fontsize=16,fontweight ='bold')
plt.yticks(fontsize=16,fontweight ='bold')
plt.legend(fontsize=16)
plt.show()

# %%
# Distribution of age with income categories
ax= sns.FacetGrid(CI,col='Income')
ax.map(sns.distplot,'Age')
plt.show()

# %% [markdown]
# So let dive into workclass and see what insight we get from there.

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('rainbow')
plt.figure(figsize=(10,10))
CI['Workclass'].value_counts().plot.pie(explode=[0,0.1,0.125,0.175,0.225,0.25,0.3,0.7],autopct='%2.1f%%',
                                          textprops ={ 'fontsize':13}, shadow=True)
plt.title('Population distribution as per Workclass', fontsize=20,fontweight ='bold')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14,9))
p = sns.countplot(CI['Workclass'], hue=CI['Income'], palette='hsv')
plt.title('Income distribution as per Workclass', fontsize=22, fontweight='bold')
p.set_xlabel('Workclass',fontsize=18,fontweight ='bold')
plt.xticks(fontsize=16,fontweight ='bold',rotation=30)
plt.yticks(fontsize=16,fontweight ='bold')
plt.legend(fontsize=16)
plt.show()

# %%
pd.crosstab(CI['Income'],CI["Workclass"], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_729ad_row0_col0{
#             background-color:  #a1d066;
#             color:  #000000;
#         }#T_729ad_row0_col1{
#             background-color:  #6bb566;
#             color:  #000000;
#         }#T_729ad_row0_col2,#T_729ad_row0_col7,#T_729ad_row2_col0,#T_729ad_row2_col1,#T_729ad_row2_col2,#T_729ad_row2_col3,#T_729ad_row2_col4,#T_729ad_row2_col5,#T_729ad_row2_col6,#T_729ad_row2_col7,#T_729ad_row2_col8{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }#T_729ad_row0_col3{
#             background-color:  #44a266;
#             color:  #000000;
#         }#T_729ad_row0_col4,#T_729ad_row1_col0,#T_729ad_row1_col1,#T_729ad_row1_col2,#T_729ad_row1_col3,#T_729ad_row1_col5,#T_729ad_row1_col6,#T_729ad_row1_col7,#T_729ad_row1_col8{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_729ad_row0_col5{
#             background-color:  #66b266;
#             color:  #000000;
#         }#T_729ad_row0_col6{
#             background-color:  #5faf66;
#             color:  #000000;
#         }#T_729ad_row0_col8{
#             background-color:  #51a866;
#             color:  #000000;
#         }#T_729ad_row1_col4{
#             background-color:  #cbe566;
#             color:  #000000;
#         }</style><table id="T_729ad_" ><thead>    <tr>        <th class="index_name level0" >Workclass</th>        <th class="col_heading level0 col0" > Federal-gov</th>        <th class="col_heading level0 col1" > Local-gov</th>        <th class="col_heading level0 col2" > Never-worked</th>        <th class="col_heading level0 col3" > Private</th>        <th class="col_heading level0 col4" > Self-emp-inc</th>        <th class="col_heading level0 col5" > Self-emp-not-inc</th>        <th class="col_heading level0 col6" > State-gov</th>        <th class="col_heading level0 col7" > Without-pay</th>        <th class="col_heading level0 col8" >All</th>    </tr>    <tr>        <th class="index_name level0" >Income</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_729ad_level0_row0" class="row_heading level0 row0" > <=50K</th>
#                         <td id="T_729ad_row0_col0" class="data row0 col0" >589</td>
#                         <td id="T_729ad_row0_col1" class="data row0 col1" >1476</td>
#                         <td id="T_729ad_row0_col2" class="data row0 col2" >7</td>
#                         <td id="T_729ad_row0_col3" class="data row0 col3" >19357</td>
#                         <td id="T_729ad_row0_col4" class="data row0 col4" >494</td>
#                         <td id="T_729ad_row0_col5" class="data row0 col5" >1816</td>
#                         <td id="T_729ad_row0_col6" class="data row0 col6" >944</td>
#                         <td id="T_729ad_row0_col7" class="data row0 col7" >14</td>
#                         <td id="T_729ad_row0_col8" class="data row0 col8" >24697</td>
#             </tr>
#             <tr>
#                         <th id="T_729ad_level0_row1" class="row_heading level0 row1" > >50K</th>
#                         <td id="T_729ad_row1_col0" class="data row1 col0" >371</td>
#                         <td id="T_729ad_row1_col1" class="data row1 col1" >617</td>
#                         <td id="T_729ad_row1_col2" class="data row1 col2" >0</td>
#                         <td id="T_729ad_row1_col3" class="data row1 col3" >5152</td>
#                         <td id="T_729ad_row1_col4" class="data row1 col4" >622</td>
#                         <td id="T_729ad_row1_col5" class="data row1 col5" >724</td>
#                         <td id="T_729ad_row1_col6" class="data row1 col6" >353</td>
#                         <td id="T_729ad_row1_col7" class="data row1 col7" >0</td>
#                         <td id="T_729ad_row1_col8" class="data row1 col8" >7839</td>
#             </tr>
#             <tr>
#                         <th id="T_729ad_level0_row2" class="row_heading level0 row2" >All</th>
#                         <td id="T_729ad_row2_col0" class="data row2 col0" >960</td>
#                         <td id="T_729ad_row2_col1" class="data row2 col1" >2093</td>
#                         <td id="T_729ad_row2_col2" class="data row2 col2" >7</td>
#                         <td id="T_729ad_row2_col3" class="data row2 col3" >24509</td>
#                         <td id="T_729ad_row2_col4" class="data row2 col4" >1116</td>
#                         <td id="T_729ad_row2_col5" class="data row2 col5" >2540</td>
#                         <td id="T_729ad_row2_col6" class="data row2 col6" >1297</td>
#                         <td id="T_729ad_row2_col7" class="data row2 col7" >14</td>
#                         <td id="T_729ad_row2_col8" class="data row2 col8" >32536</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # Education Vs Income

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('rainbow')
plt.figure(figsize=(10,10))
CI['Education'].value_counts().plot.pie(autopct='%2.1f%%', textprops ={ 'fontsize':13}, shadow=True)
plt.title('Population distribution as per Education', fontsize=20,fontweight ='bold')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14,9))
p = sns.countplot(CI['Education'], hue=CI['Income'], palette='hsv')
plt.title('Income distribution as per Education', fontsize=22, fontweight='bold')
p.set_xlabel('Education',fontsize=18,fontweight ='bold')
plt.xticks(fontsize=16,fontweight ='bold',rotation=30)
plt.yticks(fontsize=16,fontweight ='bold')
plt.legend(fontsize=16)
plt.show()

# %%
pd.crosstab(CI['Education'],CI["Workclass"], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_4c87c_row0_col0,#T_4c87c_row2_col0,#T_4c87c_row2_col1,#T_4c87c_row2_col4,#T_4c87c_row2_col5,#T_4c87c_row2_col6,#T_4c87c_row3_col3,#T_4c87c_row3_col5,#T_4c87c_row4_col5,#T_4c87c_row5_col6,#T_4c87c_row10_col3{
#             background-color:  #fefe66;
#             color:  #000000;
#         }#T_4c87c_row0_col1,#T_4c87c_row1_col1,#T_4c87c_row1_col4,#T_4c87c_row2_col3,#T_4c87c_row2_col8,#T_4c87c_row5_col4,#T_4c87c_row6_col5,#T_4c87c_row6_col8,#T_4c87c_row14_col1{
#             background-color:  #fcfe66;
#             color:  #000000;
#         }#T_4c87c_row0_col2,#T_4c87c_row15_col2{
#             background-color:  #b6db66;
#             color:  #000000;
#         }#T_4c87c_row0_col3,#T_4c87c_row7_col3,#T_4c87c_row7_col5,#T_4c87c_row7_col6,#T_4c87c_row14_col0{
#             background-color:  #f8fc66;
#             color:  #000000;
#         }#T_4c87c_row0_col4,#T_4c87c_row5_col3,#T_4c87c_row5_col8,#T_4c87c_row6_col3,#T_4c87c_row10_col0,#T_4c87c_row14_col8{
#             background-color:  #fbfd66;
#             color:  #000000;
#         }#T_4c87c_row0_col5,#T_4c87c_row0_col8,#T_4c87c_row1_col5{
#             background-color:  #f9fc66;
#             color:  #000000;
#         }#T_4c87c_row0_col6,#T_4c87c_row1_col0,#T_4c87c_row1_col6,#T_4c87c_row4_col3,#T_4c87c_row4_col8,#T_4c87c_row5_col1,#T_4c87c_row6_col1,#T_4c87c_row6_col4,#T_4c87c_row10_col1,#T_4c87c_row10_col8,#T_4c87c_row14_col3{
#             background-color:  #fdfe66;
#             color:  #000000;
#         }#T_4c87c_row0_col7,#T_4c87c_row1_col7,#T_4c87c_row2_col2,#T_4c87c_row2_col7,#T_4c87c_row3_col0,#T_4c87c_row3_col1,#T_4c87c_row3_col2,#T_4c87c_row3_col4,#T_4c87c_row3_col6,#T_4c87c_row3_col7,#T_4c87c_row3_col8,#T_4c87c_row4_col0,#T_4c87c_row4_col1,#T_4c87c_row4_col2,#T_4c87c_row4_col4,#T_4c87c_row4_col6,#T_4c87c_row4_col7,#T_4c87c_row5_col0,#T_4c87c_row6_col0,#T_4c87c_row6_col2,#T_4c87c_row6_col6,#T_4c87c_row6_col7,#T_4c87c_row7_col2,#T_4c87c_row8_col2,#T_4c87c_row8_col7,#T_4c87c_row9_col2,#T_4c87c_row9_col7,#T_4c87c_row10_col2,#T_4c87c_row10_col7,#T_4c87c_row12_col2,#T_4c87c_row12_col7,#T_4c87c_row13_col0,#T_4c87c_row13_col1,#T_4c87c_row13_col2,#T_4c87c_row13_col3,#T_4c87c_row13_col4,#T_4c87c_row13_col5,#T_4c87c_row13_col6,#T_4c87c_row13_col7,#T_4c87c_row13_col8,#T_4c87c_row14_col2,#T_4c87c_row14_col7{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_4c87c_row1_col2,#T_4c87c_row5_col2,#T_4c87c_row11_col2{
#             background-color:  #dbed66;
#             color:  #000000;
#         }#T_4c87c_row1_col3,#T_4c87c_row7_col1,#T_4c87c_row8_col0,#T_4c87c_row8_col1,#T_4c87c_row8_col3,#T_4c87c_row8_col5,#T_4c87c_row8_col8{
#             background-color:  #f5fa66;
#             color:  #000000;
#         }#T_4c87c_row1_col8,#T_4c87c_row7_col4,#T_4c87c_row7_col8,#T_4c87c_row8_col4,#T_4c87c_row8_col6,#T_4c87c_row10_col4{
#             background-color:  #f7fb66;
#             color:  #000000;
#         }#T_4c87c_row5_col5,#T_4c87c_row12_col3{
#             background-color:  #f6fa66;
#             color:  #000000;
#         }#T_4c87c_row5_col7,#T_4c87c_row7_col7,#T_4c87c_row12_col4,#T_4c87c_row14_col4{
#             background-color:  #edf666;
#             color:  #000000;
#         }#T_4c87c_row7_col0{
#             background-color:  #f1f866;
#             color:  #000000;
#         }#T_4c87c_row9_col0,#T_4c87c_row15_col8{
#             background-color:  #c7e366;
#             color:  #000000;
#         }#T_4c87c_row9_col1{
#             background-color:  #c6e266;
#             color:  #000000;
#         }#T_4c87c_row9_col3{
#             background-color:  #d9ec66;
#             color:  #000000;
#         }#T_4c87c_row9_col4{
#             background-color:  #c1e066;
#             color:  #000000;
#         }#T_4c87c_row9_col5{
#             background-color:  #d7eb66;
#             color:  #000000;
#         }#T_4c87c_row9_col6,#T_4c87c_row11_col6{
#             background-color:  #cbe566;
#             color:  #000000;
#         }#T_4c87c_row9_col8,#T_4c87c_row12_col1{
#             background-color:  #d6eb66;
#             color:  #000000;
#         }#T_4c87c_row10_col5,#T_4c87c_row14_col6{
#             background-color:  #fafc66;
#             color:  #000000;
#         }#T_4c87c_row10_col6,#T_4c87c_row12_col0{
#             background-color:  #eef666;
#             color:  #000000;
#         }#T_4c87c_row11_col0{
#             background-color:  #b9dc66;
#             color:  #000000;
#         }#T_4c87c_row11_col1{
#             background-color:  #c2e066;
#             color:  #000000;
#         }#T_4c87c_row11_col3{
#             background-color:  #a9d466;
#             color:  #000000;
#         }#T_4c87c_row11_col4,#T_4c87c_row15_col6{
#             background-color:  #bfdf66;
#             color:  #000000;
#         }#T_4c87c_row11_col5{
#             background-color:  #a8d366;
#             color:  #000000;
#         }#T_4c87c_row11_col7{
#             background-color:  #5bad66;
#             color:  #000000;
#         }#T_4c87c_row11_col8{
#             background-color:  #add666;
#             color:  #000000;
#         }#T_4c87c_row12_col5{
#             background-color:  #f3f966;
#             color:  #000000;
#         }#T_4c87c_row12_col6{
#             background-color:  #deee66;
#             color:  #000000;
#         }#T_4c87c_row12_col8,#T_4c87c_row14_col5{
#             background-color:  #f2f866;
#             color:  #000000;
#         }#T_4c87c_row15_col0{
#             background-color:  #bcde66;
#             color:  #000000;
#         }#T_4c87c_row15_col1{
#             background-color:  #d1e866;
#             color:  #000000;
#         }#T_4c87c_row15_col3{
#             background-color:  #c5e266;
#             color:  #000000;
#         }#T_4c87c_row15_col4{
#             background-color:  #cce666;
#             color:  #000000;
#         }#T_4c87c_row15_col5{
#             background-color:  #cfe766;
#             color:  #000000;
#         }#T_4c87c_row15_col7{
#             background-color:  #c9e466;
#             color:  #000000;
#         }#T_4c87c_row16_col0,#T_4c87c_row16_col1,#T_4c87c_row16_col2,#T_4c87c_row16_col3,#T_4c87c_row16_col4,#T_4c87c_row16_col5,#T_4c87c_row16_col6,#T_4c87c_row16_col7,#T_4c87c_row16_col8{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_4c87c_" ><thead>    <tr>        <th class="index_name level0" >Workclass</th>        <th class="col_heading level0 col0" > Federal-gov</th>        <th class="col_heading level0 col1" > Local-gov</th>        <th class="col_heading level0 col2" > Never-worked</th>        <th class="col_heading level0 col3" > Private</th>        <th class="col_heading level0 col4" > Self-emp-inc</th>        <th class="col_heading level0 col5" > Self-emp-not-inc</th>        <th class="col_heading level0 col6" > State-gov</th>        <th class="col_heading level0 col7" > Without-pay</th>        <th class="col_heading level0 col8" >All</th>    </tr>    <tr>        <th class="index_name level0" >Education</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4c87c_level0_row0" class="row_heading level0 row0" > 10th</th>
#                         <td id="T_4c87c_row0_col0" class="data row0 col0" >6</td>
#                         <td id="T_4c87c_row0_col1" class="data row0 col1" >31</td>
#                         <td id="T_4c87c_row0_col2" class="data row0 col2" >2</td>
#                         <td id="T_4c87c_row0_col3" class="data row0 col3" >795</td>
#                         <td id="T_4c87c_row0_col4" class="data row0 col4" >19</td>
#                         <td id="T_4c87c_row0_col5" class="data row0 col5" >67</td>
#                         <td id="T_4c87c_row0_col6" class="data row0 col6" >13</td>
#                         <td id="T_4c87c_row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_4

# %%
# Percentage Income distribution in terms of Education
sns.set_palette('rainbow')
table = pd.crosstab(CI['Education'], CI['Income'])
(table.div(table.sum(axis=1),axis=0)*100).plot(kind='bar',stacked=True,figsize=(15,7))
plt.title('Percent Income distribution as per Education', fontsize=22, fontweight='bold')
plt.xlabel('Education', fontsize=18,fontweight='bold')
plt.ylabel('Population', fontsize=18,fontweight='bold')
plt.xticks(fontweight ='bold')
plt.show()

# %% [markdown]
# # Impact of Marital Status on Income

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('Set1')
plt.figure(figsize=(10,10))
CI['Marital_status'].value_counts().plot.pie(autopct='%2.1f%%', explode=[0.075,0.1,0.125,0.15,0.175,0.2,0.225],
                                             textprops ={'fontsize':13,'fontweight':'bold'},shadow=True)
plt.title('Population distribution as per Marital Status', fontsize=20,fontweight ='bold')
plt.tight_layout()
plt.show()

# %%
# Percentage Income distribution in terms of Education
sns.set_palette('rainbow')
table = pd.crosstab(CI['Marital_status'], CI['Income'])
(table.div(table.sum(axis=1),axis=0)*100).plot(kind='bar',stacked=True,figsize=(12,8))
plt.title('Percent Income distribution as per Marital Status', fontsize=22, fontweight='bold')
plt.xlabel('Marital Status', fontsize=18,fontweight='bold')
plt.ylabel('Population', fontsize=18,fontweight='bold')
plt.xticks(fontweight ='bold')
plt.show()

# %%
pd.crosstab(CI['Marital_status'],CI["Income"], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_d4e2e_row0_col0{
#             background-color:  #d6eb66;
#             color:  #000000;
#         }#T_d4e2e_row0_col1{
#             background-color:  #f1f866;
#             color:  #000000;
#         }#T_d4e2e_row0_col2{
#             background-color:  #ddee66;
#             color:  #000000;
#         }#T_d4e2e_row1_col0,#T_d4e2e_row1_col1,#T_d4e2e_row1_col2,#T_d4e2e_row3_col1{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_d4e2e_row2_col0{
#             background-color:  #aad466;
#             color:  #000000;
#         }#T_d4e2e_row2_col1{
#             background-color:  #259266;
#             color:  #000000;
#         }#T_d4e2e_row2_col2{
#             background-color:  #8ac466;
#             color:  #000000;
#         }#T_d4e2e_row3_col0,#T_d4e2e_row3_col2{
#             background-color:  #fcfe66;
#             color:  #000000;
#         }#T_d4e2e_row4_col0{
#             background-color:  #96cb66;
#             color:  #000000;
#         }#T_d4e2e_row4_col1{
#             background-color:  #f0f866;
#             color:  #000000;
#         }#T_d4e2e_row4_col2{
#             background-color:  #acd666;
#             color:  #000000;
#         }#T_d4e2e_row5_col0,#T_d4e2e_row6_col0{
#             background-color:  #f6fa66;
#             color:  #000000;
#         }#T_d4e2e_row5_col1{
#             background-color:  #fefe66;
#             color:  #000000;
#         }#T_d4e2e_row5_col2,#T_d4e2e_row6_col2{
#             background-color:  #f8fc66;
#             color:  #000000;
#         }#T_d4e2e_row6_col1{
#             background-color:  #fdfe66;
#             color:  #000000;
#         }#T_d4e2e_row7_col0,#T_d4e2e_row7_col1,#T_d4e2e_row7_col2{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_d4e2e_" ><thead>    <tr>        <th class="index_name level0" >Income</th>        <th class="col_heading level0 col0" > <=50K</th>        <th class="col_heading level0 col1" > >50K</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Marital_status</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d4e2e_level0_row0" class="row_heading level0 row0" > Divorced</th>
#                         <td id="T_d4e2e_row0_col0" class="data row0 col0" >3978</td>
#                         <td id="T_d4e2e_row0_col1" class="data row0 col1" >463</td>
#                         <td id="T_d4e2e_row0_col2" class="data row0 col2" >4441</td>
#             </tr>
#             <tr>
#                         <th id="T_d4e2e_level0_row1" class="row_heading level0 row1" > Married-AF-spouse</th>
#                         <td id="T_d4e2e_row1_col0" class="data row1 col0" >13</td>
#                         <td id="T_d4e2e_row1_col1" class="data row1 col1" >10</td>
#                         <td id="T_d4e2e_row1_col2" class="data row1 col2" >23</td>
#             </tr>
#             <tr>
#                         <th id="T_d4e2e_level0_row2" class="row_heading level0 row2" > Married-civ-spouse</th>
#                         <td id="T_d4e2e_row2_col0" class="data row2 col0" >8280</td>
#                         <td id="T_d4e2e_row2_col1" class="data row2 col1" >6690</td>
#                         <td id="T_d4e2e_row2_col2" class="data row2 col2" >14970</td>
#             </tr>
#             <tr>
#                         <th id="T_d4e2e_level0_row3" class="row_heading level0 row3" > Married-spouse-absent</th>
#                         <td id="T_d4e2e_row3_col0" class="data row3 col0" >384</td>
#                         <td id="T_d4e2e_row3_col1" class="data row3 col1" >34</td>
#                         <td id="T_d4e2e_row3_col2" class="data row3 col2" >418</td>
#             </tr>
#             <tr>
#                         <th id="T_d4e2e_level0_row4" class="row_heading level0 row4" > Never-married</th>
#                         <td id="T_d4e2e_row4_col0" class="data row4 col0" >10175</td>
#                         <td id="T_d4e2e_row4_col1" class="data row4 col1" >491</td>
#                         <td id="T_d4e2e_row4_col2" class="data row4 col2" >10666</td>
#             </tr>
#             <tr>
#                         <th id="T_d4e2e_level0_row5" class="row_heading level0 row5" > Separated</th>
#                         <td id="T_d4e2e_row5_col0" class="data row5 col0" >959</td>
#                         <td id="T_d4e2e_row5_col1" class="data row5 col1" >66</td>
#                         <td id="T_d4e2e_row5_col2" class="data row5 col2" >1025</td>
#             </tr>
#             <tr>
#                         <th id="T_d4e2e_level0_row6" class="row_heading level0 row6" > Widowed</th>
#                         <td id="T_d4e2e_row6_col0" class="data row6 col0" >908</td>
#                         <td id="T_d4e2e_row6_col1" class="data row6 col1" >85</td>
#                         <td id="T_d4e2e_row6_col2" class="data row6 col2" >993</td>
#             </tr>
#             <tr>
#                         <th id="T_d4e2e_level0_row7" class="row_heading level0 row7" >All</th>
#                         <td id="T_d4e2e_row7_col0" class="data row7 col0" >24697</td>
#                         <td id="T_d4e2e_row7_col1" class="data row7 col1" >7839</td>
#                         <td id="T_d4e2e_row7_col2" class="data row7 col2" >32536</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # Occupation VS Income

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('rainbow')
plt.figure(figsize=(10,10))
CI['Occupation'].value_counts().plot.pie(autopct='%2.1f%%', textprops ={ 'fontsize':13}, shadow=True)
plt.title('Population distribution as per Occupation', fontsize=20,fontweight ='bold')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14,9))
p = sns.countplot(CI['Occupation'], hue=CI['Income'], palette='cool')
plt.title('Income distribution as per Occupation', fontsize=22, fontweight='bold')
p.set_xlabel('Occupation',fontsize=18,fontweight ='bold')
plt.xticks(fontsize=16,rotation=90)
plt.yticks(fontsize=16,fontweight ='bold')
plt.legend(fontsize=16)
plt.show()

# %%
# Percentage Income distribution in terms of Education
sns.set_palette('rainbow')
table = pd.crosstab(CI['Occupation'], CI['Income'])
(table.div(table.sum(axis=1),axis=0)*100).plot(kind='bar',stacked=True,figsize=(12,8))
plt.title('Percent Income distribution as per Occupation', fontsize=22, fontweight='bold')
plt.xlabel('Occupation', fontsize=18,fontweight='bold')
plt.ylabel('Population', fontsize=18,fontweight='bold')
plt.xticks(fontweight ='bold')
plt.show()

# %%
pd.crosstab(CI['Occupation'],CI["Income"], margins=True).style.background_gradient(cmap='winter_r')
# Out:
# <style  type="text/css" >
# #T_68d65_row0_col0{
#             background-color:  #00de90;
#             color:  #000000;
#         }#T_68d65_row0_col1{
#             background-color:  #00ef88;
#             color:  #000000;
#         }#T_68d65_row0_col2{
#             background-color:  #00e28e;
#             color:  #000000;
#         }#T_68d65_row1_col0,#T_68d65_row1_col1,#T_68d65_row1_col2,#T_68d65_row8_col1{
#             background-color:  #00ff80;
#             color:  #000000;
#         }#T_68d65_row2_col0,#T_68d65_row2_col2,#T_68d65_row7_col0,#T_68d65_row11_col1{
#             background-color:  #00df90;
#             color:  #000000;
#         }#T_68d65_row2_col1{
#             background-color:  #00e18e;
#             color:  #000000;
#         }#T_68d65_row3_col0{
#             background-color:  #00ea8a;
#             color:  #000000;
#         }#T_68d65_row3_col1{
#             background-color:  #00bfa0;
#             color:  #000000;
#         }#T_68d65_row3_col2{
#             background-color:  #00e08f;
#             color:  #000000;
#         }#T_68d65_row4_col0,#T_68d65_row12_col1{
#             background-color:  #00f684;
#             color:  #000000;
#         }#T_68d65_row4_col1{
#             background-color:  #00fc81;
#             color:  #000000;
#         }#T_68d65_row4_col2,#T_68d65_row12_col2{
#             background-color:  #00f883;
#             color:  #000000;
#         }#T_68d65_row5_col0,#T_68d65_row13_col0{
#             background-color:  #00f286;
#             color:  #000000;
#         }#T_68d65_row5_col1{
#             background-color:  #00fd80;
#             color:  #000000;
#         }#T_68d65_row5_col2,#T_68d65_row13_col1{
#             background-color:  #00f584;
#             color:  #000000;
#         }#T_68d65_row6_col0{
#             background-color:  #00ed88;
#             color:  #000000;
#         }#T_68d65_row6_col1{
#             background-color:  #00f784;
#             color:  #000000;
#         }#T_68d65_row6_col2{
#             background-color:  #00f087;
#             color:  #000000;
#         }#T_68d65_row7_col1,#T_68d65_row10_col0{
#             background-color:  #00fb82;
#             color:  #000000;
#         }#T_68d65_row7_col2{
#             background-color:  #00e68c;
#             color:  #000000;
#         }#T_68d65_row8_col0,#T_68d65_row8_col2{
#             background-color:  #00fe80;
#             color:  #000000;
#         }#T_68d65_row9_col0{
#             background-color:  #00d793;
#             color:  #000000;
#         }#T_68d65_row9_col1{
#             background-color:  #00bda0;
#             color:  #000000;
#         }#T_68d65_row9_col2{
#             background-color:  #00d196;
#             color:  #000000;
#         }#T_68d65_row10_col1,#T_68d65_row12_col0{
#             background-color:  #00f982;
#             color:  #000000;
#         }#T_68d65_row10_col2{
#             background-color:  #00fa82;
#             color:  #000000;
#         }#T_68d65_row11_col0{
#             background-color:  #00e48d;
#             color:  #000000;
#         }#T_68d65_row11_col2{
#             background-color:  #00e38e;
#             color:  #000000;
#         }#T_68d65_row13_col2{
#             background-color:  #00f386;
#             color:  #000000;
#         }#T_68d65_row14_col0,#T_68d65_row14_col1,#T_68d65_row14_col2{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_68d65_" ><thead>    <tr>        <th class="index_name level0" >Income</th>        <th class="col_heading level0 col0" > <=50K</th>        <th class="col_heading level0 col1" > >50K</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Occupation</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_68d65_level0_row0" class="row_heading level0 row0" > Adm-clerical</th>
#                         <td id="T_68d65_row0_col0" class="data row0 col0" >3260</td>
#                         <td id="T_68d65_row0_col1" class="data row0 col1" >507</td>
#                         <td id="T_68d65_row0_col2" class="data row0 col2" >3767</td>
#             </tr>
#             <tr>
#                         <th id="T_68d65_level0_row1" class="row_heading level0 row1" > Armed-Forces</th>
#                         <td id="T_68d65_row1_col0" class="data row1 col0" >8</td>
#                         <td id="T_68d65_row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_68d65_row1_col2" class="data row1 col2" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_68d65_level0_row2" class="row_heading level0 row2" > Craft-repair</th>
#                         <td id="T_68d65_row2_col0" class="data row2 col0" >3165</td>
#                         <td id="T_68d65_row2_col1" class="data row2 col1" >929</td>
#                         <td id="T_68d65_row2_col2" class="data row2 col2" >4094</td>
#             </tr>
#             <tr>
#                         <th id="T_68d65_level0_row3" class="row_heading level0 row3" > Exec-managerial</th>
#                         <td id="T_68d65_row3_col0" class="data row3 col0" >2097</td>
#                         <td id="T_68d65_row3_col1" class="data row3 col1" >1968</td>
#                         <td id="T_68d65_row3_col2" class="data row3 col2" >4065</td>
#             </tr>
#             <tr>
#                         <th id="T_68d65_level0_row4" class="row_heading level0 row4" > Farming-fishing</th>
#                         <td id="T_68d65_row4_col0" class="data row4 col0" >877</td>
#                         <td id="T_68d65_row4_col1" class="data row4 col1" >115</td>
#                         <td id="T_68d65_row4_col2" class="data row4 col2" >992</td>
#             </tr>
#             <tr>
#                         <th id="T_68d65_level0_row5" class="row_heading level0 row5" > Handlers-cleaners</th>
#                         <td id="T_68d65_row5_col0" class="data row5 col0" >1283</td>
#                         <td id="T_68d65_row5_col1" class="data row5 col1" >86</td>
#                         <td id="T_68d65_row5_col2" class="data row5 col2" >1369</td>
#             </tr>
#             <tr>
#                         <th id="T_68d65_level0_row6" class="row_heading level0 row6" > Machine-op-inspct</th>
#                         <td id="T_68d65_row6_col0" class="data row6 col0" >1751</td>
#                         <td id="T_68d65_row6_col1" class="data row6 col1" >249</td>
#                         <td id="T_68d65_row6_col2" class="data row6 col2" >2000</td>
#             </tr>
#             <tr>
#                         <th id="T_68d65_level0_row7" class="row_heading level0 row7" > Other-service</th>
#                         <td id="T_68d65_row7_col0" class="data row7 col0" >3154</td>
#                         <td id="T_68d65_row7_col1" class="data row7 col1" >137</td>
#                         <td id="T_68d65_row7_col2" class="data row7 col2" >3291</td>
#             </tr>
#             <tr>
#                         <th id="T_68d65_level0_row8" class="row_heading level0 row8" > Priv-house-serv</th>
#                         <td id="T_68d65_row8_col0" class="data row8 col0" >146</td>
#                         <td id="T_68d65_row8_col1" class="data row8 col1" >1</td>
#                         <td id="T_68d65_row8_col2" class="data row8 col2" >147</td>
#             </tr>
#             <tr>
#                         <th id="T_68d65_level0_row9" class="row_heading level0 row9" > Prof-specialty</th>
#                         <td id="T_68d65_row9_col0" class="data row9 col0" >3930</td>
#                         <td id="T_68d65_row9_col1" class="data row9 col1" >2049</td>
#                         <td id="T_68d65_row9_col2" class="data row9 col2" >5979</td>
#             </tr>
#             <tr>
#                         <th id="T_68d65_level0_row10" class="row_heading level0 row10" > Protective-serv</th>
#                         <td id="T_68d65_row10_col0" class="data row10 col0" >438</td>
#                         <td id="T_68d65_row10_col1" class="data row10 col1" >211</td>
#                         <td id=

# %%
pd.crosstab(CI['Occupation'],CI["Workclass"], margins=True).style.background_gradient(cmap='winter_r')
# Out:
# <style  type="text/css" >
# #T_98bcc_row0_col0{
#             background-color:  #00abaa;
#             color:  #000000;
#         }#T_98bcc_row0_col1{
#             background-color:  #00dd90;
#             color:  #000000;
#         }#T_98bcc_row0_col2,#T_98bcc_row1_col1,#T_98bcc_row1_col2,#T_98bcc_row1_col3,#T_98bcc_row1_col4,#T_98bcc_row1_col5,#T_98bcc_row1_col6,#T_98bcc_row1_col7,#T_98bcc_row1_col8,#T_98bcc_row2_col2,#T_98bcc_row3_col2,#T_98bcc_row3_col7,#T_98bcc_row4_col2,#T_98bcc_row5_col2,#T_98bcc_row5_col4,#T_98bcc_row6_col2,#T_98bcc_row7_col2,#T_98bcc_row8_col0,#T_98bcc_row8_col1,#T_98bcc_row8_col2,#T_98bcc_row8_col4,#T_98bcc_row8_col5,#T_98bcc_row8_col6,#T_98bcc_row8_col7,#T_98bcc_row9_col7,#T_98bcc_row10_col2,#T_98bcc_row10_col5,#T_98bcc_row10_col7,#T_98bcc_row11_col1,#T_98bcc_row11_col2,#T_98bcc_row11_col7,#T_98bcc_row12_col2,#T_98bcc_row12_col4,#T_98bcc_row12_col7,#T_98bcc_row13_col2{
#             background-color:  #00ff80;
#             color:  #000000;
#         }#T_98bcc_row0_col3,#T_98bcc_row0_col8{
#             background-color:  #00e28e;
#             color:  #000000;
#         }#T_98bcc_row0_col4,#T_98bcc_row4_col8,#T_98bcc_row10_col0,#T_98bcc_row12_col3,#T_98bcc_row12_col8{
#             background-color:  #00f883;
#             color:  #000000;
#         }#T_98bcc_row0_col5,#T_98bcc_row5_col1,#T_98bcc_row10_col8{
#             background-color:  #00fa82;
#             color:  #000000;
#         }#T_98bcc_row0_col6{
#             background-color:  #00ce98;
#             color:  #000000;
#         }#T_98bcc_row0_col7{
#             background-color:  #00c99a;
#             color:  #000000;
#         }#T_98bcc_row1_col0,#T_98bcc_row4_col0,#T_98bcc_row4_col6,#T_98bcc_row6_col4,#T_98bcc_row6_col6,#T_98bcc_row11_col6,#T_98bcc_row12_col5{
#             background-color:  #00fd80;
#             color:  #000000;
#         }#T_98bcc_row2_col0,#T_98bcc_row2_col1,#T_98bcc_row7_col5{
#             background-color:  #00ee88;
#             color:  #000000;
#         }#T_98bcc_row2_col3{
#             background-color:  #00de90;
#             color:  #000000;
#         }#T_98bcc_row2_col4,#T_98bcc_row7_col6{
#             background-color:  #00e78c;
#             color:  #000000;
#         }#T_98bcc_row2_col5{
#             background-color:  #00ca9a;
#             color:  #000000;
#         }#T_98bcc_row2_col6,#T_98bcc_row4_col4,#T_98bcc_row12_col6{
#             background-color:  #00f485;
#             color:  #000000;
#         }#T_98bcc_row2_col7,#T_98bcc_row5_col7,#T_98bcc_row6_col7,#T_98bcc_row7_col7,#T_98bcc_row12_col0,#T_98bcc_row13_col7{
#             background-color:  #00ed88;
#             color:  #000000;
#         }#T_98bcc_row2_col8{
#             background-color:  #00df90;
#             color:  #000000;
#         }#T_98bcc_row3_col0{
#             background-color:  #00cf98;
#             color:  #000000;
#         }#T_98bcc_row3_col1{
#             background-color:  #00e58c;
#             color:  #000000;
#         }#T_98bcc_row3_col3,#T_98bcc_row7_col3,#T_98bcc_row11_col8{
#             background-color:  #00e38e;
#             color:  #000000;
#         }#T_98bcc_row3_col4{
#             background-color:  #00a4ad;
#             color:  #000000;
#         }#T_98bcc_row3_col5{
#             background-color:  #00d893;
#             color:  #000000;
#         }#T_98bcc_row3_col6,#T_98bcc_row9_col5,#T_98bcc_row10_col1{
#             background-color:  #00da92;
#             color:  #000000;
#         }#T_98bcc_row3_col8{
#             background-color:  #00e08f;
#             color:  #000000;
#         }#T_98bcc_row4_col1,#T_98bcc_row6_col0,#T_98bcc_row6_col5,#T_98bcc_row11_col0{
#             background-color:  #00fc81;
#             color:  #000000;
#         }#T_98bcc_row4_col3,#T_98bcc_row12_col1{
#             background-color:  #00fb82;
#             color:  #000000;
#         }#T_98bcc_row4_col5,#T_98bcc_row9_col3{
#             background-color:  #00d495;
#             color:  #000000;
#         }#T_98bcc_row4_col7{
#             background-color:  #0092b6;
#             color:  #000000;
#         }#T_98bcc_row5_col0,#T_98bcc_row7_col4,#T_98bcc_row13_col0,#T_98bcc_row13_col4{
#             background-color:  #00f982;
#             color:  #000000;
#         }#T_98bcc_row5_col3,#T_98bcc_row13_col3{
#             background-color:  #00f286;
#             color:  #000000;
#         }#T_98bcc_row5_col5,#T_98bcc_row5_col6,#T_98bcc_row6_col1,#T_98bcc_row8_col3,#T_98bcc_row8_col8,#T_98bcc_row10_col3,#T_98bcc_row10_col4{
#             background-color:  #00fe80;
#             color:  #000000;
#         }#T_98bcc_row5_col8{
#             background-color:  #00f584;
#             color:  #000000;
#         }#T_98bcc_row6_col3{
#             background-color:  #00ec89;
#             color:  #000000;
#         }#T_98bcc_row6_col8{
#             background-color:  #00f087;
#             color:  #000000;
#         }#T_98bcc_row7_col0{
#             background-color:  #00f684;
#             color:  #000000;
#         }#T_98bcc_row7_col1{
#             background-color:  #00e88b;
#             color:  #000000;
#         }#T_98bcc_row7_col8{
#             background-color:  #00e68c;
#             color:  #000000;
#         }#T_98bcc_row9_col0,#T_98bcc_row9_col8{
#             background-color:  #00d196;
#             color:  #000000;
#         }#T_98bcc_row9_col1{
#             background-color:  #00a9ab;
#             color:  #000000;
#         }#T_98bcc_row9_col2,#T_98bcc_row14_col0,#T_98bcc_row14_col1,#T_98bcc_row14_col2,#T_98bcc_row14_col3,#T_98bcc_row14_col4,#T_98bcc_row14_col5,#T_98bcc_row14_col6,#T_98bcc_row14_col7,#T_98bcc_row14_col8{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_98bcc_row9_col4{
#             background-color:  #00db92;
#             color:  #000000;
#         }#T_98bcc_row9_col6{
#             background-color:  #00aea8;
#             color:  #000000;
#         }#T_98bcc_row10_col6{
#             background-color:  #00e98a;
#             color:  #000000;
#         }#T_98bcc_row11_col3{
#             background-color:  #00e18e;
#             color:  #000000;
#         }#T_98bcc_row11_col4{
#             background-color:  #00bda0;
#             color:  #000000;
#         }#T_98bcc_row11_col5{
#             background-color:  #00d992;
#             color:  #000000;
#         }#T_98bcc_row13_col1{
#             background-color:  #00f186;
#             color:  #000000;
#         }#T_98bcc_row13_col5,#T_98bcc_row13_col8{
#             background-color:  #00f386;
#             color:  #000000;
#         }#T_98bcc_row13_col6{
#             background-color:  #00f784;
#             color:  #000000;
#         }</style><table id="T_98bcc_" ><thead>    <tr>        <th class="index_name level0" >Workclass</th>        <th class="col_heading level0 col0" > Federal-gov</th>        <th class="col_heading level0 col1" > Local-gov</th>        <th class="col_heading level0 col2" > Never-worked</th>        <th class="col_heading level0 col3" > Private</th>        <th class="col_heading level0 col4" > Self-emp-inc</th>        <th class="col_heading level0 col5" > Self-emp-not-inc</th>        <th class="col_heading level0 col6" > State-gov</th>        <th class="col_heading level0 col7" > Without-pay</th>        <th class="col_heading level0 col8" >All</th>    </tr>    <tr>        <th class="index_name level0" >Occupation</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_98bcc_level0_row0" class="row_heading level0 row0" > Adm-clerical</th>
#                         <td id="T_98bcc_row0_col0" class="data row0 col0" >317</td>
#                         <td id="T_98bcc_row0_col1" class="data row0 col1" >283</td>
#                         <td id="T_98bcc_row0_col2" class="data row0 col2" >0</td>
#                         <td id="T_98bcc_row0_col3" class="data row0 col3" >2831</td>
#                         <td id="T_98bcc_row0_col4" class="data row0 col4" >31</td

# %% [markdown]
# # Relationship VS Income

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('rainbow')
plt.figure(figsize=(10,10))
CI['Relationship'].value_counts().plot.pie(autopct='%2.1f%%',explode=[0.05,0.05,0.05,0.05,0.075,0.075],
                                           textprops ={'fontweight' :'bold', 'fontsize':13}, shadow=True)
plt.title('Population distribution as per Relationship', fontsize=22,fontweight ='bold')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,8))
p = sns.countplot(CI['Relationship'], hue=CI['Income'], palette='cool')
plt.title('Income distribution as per Occupation', fontsize=22, fontweight='bold')
p.set_xlabel('Relationship',fontsize=18,fontweight ='bold')
plt.xticks(fontsize=16,rotation=20)
plt.yticks(fontsize=16,fontweight ='bold')
plt.legend(fontsize=16)
plt.show()

# %% [markdown]
# # Race vs Income

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('gist_rainbow_r')
plt.figure(figsize=(10,10))
CI['Race'].value_counts().plot.pie(autopct='%2.1f%%',explode=[0.05,0.05,0.05,0.05,0.075],
                                           textprops ={'fontweight' :'bold', 'fontsize':13}, shadow=True)
plt.title('Race distribution as per Relationship', fontsize=22,fontweight ='bold')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,8))
p = sns.countplot(CI['Race'], hue=CI['Income'], palette='cool')
plt.title('Race distribution as per Occupation', fontsize=22, fontweight='bold')
p.set_xlabel('Race',fontsize=18,fontweight ='bold')
plt.xticks(fontsize=16,rotation=20)
plt.yticks(fontsize=16,fontweight ='bold')
plt.legend(fontsize=16)
plt.show()

# %%
# Percentage Income distribution in terms of Education
sns.set_palette('viridis')
table = pd.crosstab(CI['Race'], CI['Income'])
(table.div(table.sum(axis=1),axis=0)*100).plot(kind='bar',stacked=True,figsize=(12,8))
plt.title('Percent Income distribution as per Race', fontsize=22, fontweight='bold')
plt.xlabel('Race', fontsize=18,fontweight='bold')
plt.ylabel('Population', fontsize=18,fontweight='bold')
plt.xticks(fontweight ='bold')
plt.show()

# %% [markdown]
# # Sex Vs Income

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('plasma')
f,ax=plt.subplots(1,2,figsize=(18,8))
CI['Sex'].value_counts().plot.pie(explode=[0,0.1],autopct='%3.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':18}, ax=ax[0],shadow=True)
ax[0].set_title('Population Distribution', fontsize=22,fontweight ='bold')
ax[0].set_ylabel('')
sns.countplot('Sex',hue=CI['Income'] ,data=CI,ax=ax[1])
ax[1].set_title('Income Distribution',fontsize=22,fontweight ='bold')
ax[1].set_xlabel("Income",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=18,fontweight ='bold')
plt.show()

# %% [markdown]
# Let find in which profession these women involved in .

# %%
pd.crosstab(CI['Occupation'],[CI.Sex,CI.Income], margins=True).style.background_gradient(cmap='winter_r')
# Out:
# <style  type="text/css" >
# #T_4c337_row0_col0{
#             background-color:  #00c19e;
#             color:  #000000;
#         }#T_4c337_row0_col1,#T_4c337_row7_col0,#T_4c337_row9_col4{
#             background-color:  #00d196;
#             color:  #000000;
#         }#T_4c337_row0_col2,#T_4c337_row6_col4{
#             background-color:  #00f087;
#             color:  #000000;
#         }#T_4c337_row0_col3,#T_4c337_row7_col1,#T_4c337_row13_col3{
#             background-color:  #00f485;
#             color:  #000000;
#         }#T_4c337_row0_col4{
#             background-color:  #00e28e;
#             color:  #000000;
#         }#T_4c337_row1_col0,#T_4c337_row1_col1,#T_4c337_row1_col2,#T_4c337_row1_col3,#T_4c337_row1_col4,#T_4c337_row4_col1,#T_4c337_row5_col1,#T_4c337_row8_col1,#T_4c337_row8_col2,#T_4c337_row8_col3{
#             background-color:  #00ff80;
#             color:  #000000;
#         }#T_4c337_row2_col0,#T_4c337_row10_col4,#T_4c337_row12_col2{
#             background-color:  #00fa82;
#             color:  #000000;
#         }#T_4c337_row2_col1,#T_4c337_row4_col3,#T_4c337_row5_col0,#T_4c337_row6_col1{
#             background-color:  #00fb82;
#             color:  #000000;
#         }#T_4c337_row2_col2{
#             background-color:  #00cd98;
#             color:  #000000;
#         }#T_4c337_row2_col3,#T_4c337_row11_col3{
#             background-color:  #00dd90;
#             color:  #000000;
#         }#T_4c337_row2_col4{
#             background-color:  #00df90;
#             color:  #000000;
#         }#T_4c337_row3_col0,#T_4c337_row7_col2{
#             background-color:  #00e88b;
#             color:  #000000;
#         }#T_4c337_row3_col1{
#             background-color:  #00c39e;
#             color:  #000000;
#         }#T_4c337_row3_col2,#T_4c337_row6_col2,#T_4c337_row13_col2{
#             background-color:  #00eb8a;
#             color:  #000000;
#         }#T_4c337_row3_col3{
#             background-color:  #00bfa0;
#             color:  #000000;
#         }#T_4c337_row3_col4,#T_4c337_row11_col0{
#             background-color:  #00e08f;
#             color:  #000000;
#         }#T_4c337_row4_col0,#T_4c337_row8_col4,#T_4c337_row10_col0,#T_4c337_row13_col1{
#             background-color:  #00fe80;
#             color:  #000000;
#         }#T_4c337_row4_col2{
#             background-color:  #00f286;
#             color:  #000000;
#         }#T_4c337_row4_col4,#T_4c337_row10_col3,#T_4c337_row12_col4{
#             background-color:  #00f883;
#             color:  #000000;
#         }#T_4c337_row5_col2{
#             background-color:  #00ed88;
#             color:  #000000;
#         }#T_4c337_row5_col3,#T_4c337_row7_col3,#T_4c337_row8_col0{
#             background-color:  #00fc81;
#             color:  #000000;
#         }#T_4c337_row5_col4{
#             background-color:  #00f584;
#             color:  #000000;
#         }#T_4c337_row6_col0{
#             background-color:  #00f186;
#             color:  #000000;
#         }#T_4c337_row6_col3,#T_4c337_row12_col0{
#             background-color:  #00f784;
#             color:  #000000;
#         }#T_4c337_row7_col4,#T_4c337_row11_col2{
#             background-color:  #00e68c;
#             color:  #000000;
#         }#T_4c337_row9_col0{
#             background-color:  #00cc99;
#             color:  #000000;
#         }#T_4c337_row9_col1{
#             background-color:  #00a1ae;
#             color:  #000000;
#         }#T_4c337_row9_col2{
#             background-color:  #00de90;
#             color:  #000000;
#         }#T_4c337_row9_col3{
#             background-color:  #00c29e;
#             color:  #000000;
#         }#T_4c337_row10_col1,#T_4c337_row13_col0{
#             background-color:  #00fd80;
#             color:  #000000;
#         }#T_4c337_row10_col2{
#             background-color:  #00f982;
#             color:  #000000;
#         }#T_4c337_row11_col1{
#             background-color:  #00ec89;
#             color:  #000000;
#         }#T_4c337_row11_col4{
#             background-color:  #00e38e;
#             color:  #000000;
#         }#T_4c337_row12_col1,#T_4c337_row12_col3{
#             background-color:  #00f684;
#             color:  #000000;
#         }#T_4c337_row13_col4{
#             background-color:  #00f386;
#             color:  #000000;
#         }#T_4c337_row14_col0,#T_4c337_row14_col1,#T_4c337_row14_col2,#T_4c337_row14_col3,#T_4c337_row14_col4{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }</style><table id="T_4c337_" ><thead>    <tr>        <th class="index_name level0" >Sex</th>        <th class="col_heading level0 col0" colspan="2"> Female</th>        <th class="col_heading level0 col2" colspan="2"> Male</th>        <th class="col_heading level0 col4" >All</th>    </tr>    <tr>        <th class="index_name level1" >Income</th>        <th class="col_heading level1 col0" > <=50K</th>        <th class="col_heading level1 col1" > >50K</th>        <th class="col_heading level1 col2" > <=50K</th>        <th class="col_heading level1 col3" > >50K</th>        <th class="col_heading level1 col4" ></th>    </tr>    <tr>        <th class="index_name level0" >Occupation</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4c337_level0_row0" class="row_heading level0 row0" > Adm-clerical</th>
#                         <td id="T_4c337_row0_col0" class="data row0 col0" >2323</td>
#                         <td id="T_4c337_row0_col1" class="data row0 col1" >212</td>
#                         <td id="T_4c337_row0_col2" class="data row0 col2" >937</td>
#                         <td id="T_4c337_row0_col3" class="data row0 col3" >295</td>
#                         <td id="T_4c337_row0_col4" class="data row0 col4" >3767</td>
#             </tr>
#             <tr>
#                         <th id="T_4c337_level0_row1" class="row_heading level0 row1" > Armed-Forces</th>
#                         <td id="T_4c337_row1_col0" class="data row1 col0" >0</td>
#                         <td id="T_4c337_row1_col1" class="data row1 col1" >0</td>
#                         <td id="T_4c337_row1_col2" class="data row1 col2" >8</td>
#                         <td id="T_4c337_row1_col3" class="data row1 col3" >1</td>
#                         <td id="T_4c337_row1_col4" class="data row1 col4" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_4c337_level0_row2" class="row_heading level0 row2" > Craft-repair</th>
#                         <td id="T_4c337_row2_col0" class="data row2 col0" >202</td>
#                         <td id="T_4c337_row2_col1" class="data row2 col1" >20</td>
#                         <td id="T_4c337_row2_col2" class="data row2 col2" >2963</td>
#                         <td id="T_4c337_row2_col3" class="data row2 col3" >909</td>
#                         <td id="T_4c337_row2_col4" class="data row2 col4" >4094</td>
#             </tr>
#             <tr>
#                         <th id="T_4c337_level0_row3" class="row_heading level0 row3" > Exec-managerial</th>
#                         <td id="T_4c337_row3_col0" class="data row3 col0" >879</td>
#                         <td id="T_4c337_row3_col1" class="data row3 col1" >280</td>
#                         <td id="T_4c337_row3_col2" class="data row3 col2" >1218</td>
#                         <td id="T_4c337_row3_col3" class="data row3 col3" >1688</td>
#                         <td id="T_4c337_row3_col4" class="data row3 col4" >4065</td>
#             </tr>
#             <tr>
#                         <th id="T_4c337_level0_row4" class="row_heading level0 row4" > Farming-fishing</th>
#                         <td id="T_4c337_row4_col0" class="data row4 col0" >63</td>
#                         <td id="T_4c337_row4_col1" class="data row4 col1" >2</td>
#                         <td id="T_4c337_row4_col2" class="data row4 col2" >814</td>
#                         <td id="T_4c337_row4_col3" class="data row4 col3" >113</td>
#                         <td id="T_4c337_row4_col4" class="data row4 col4" >992</td>
#             </tr>

# %%
# Setting Parameters
plt.rcParams['figure.figsize'] = [15,15]
sns.set(style = 'darkgrid')

# This Violin plot show how capital gain, loss, hours per week and education vary with the race of the people
plt.subplot(2,2,1)
sns.violinplot(x = CI['Race'], y = CI['Capital_gain'], data = CI);
plt.subplot(2,2,2)
sns.violinplot(x = CI['Race'], y = CI['Capital_loss'], data = CI);
plt.subplot(2,2,3)
sns.violinplot(x = CI['Race'], y = CI['Hours_per_week'], data = CI);
plt.subplot(2,2,4)
sns.violinplot(x = CI['Race'], y = CI['Education_num'], data = CI);

# %%
# This shows the hours per week according to the education of the person
sns.set(rc={'figure.figsize':(12,8)})
sns_grad = sns.barplot(x = CI['Education'], y = CI['Hours_per_week'], data = CI)
plt.setp(sns_grad.get_xticklabels(), rotation=90)
plt.show()

# %%
# Visualizing how the income changes for Native country of the people
plt.figure(figsize=(15,15))
plt.title("Income in each Native Country")
sns.pointplot(x='Native_country',y='Education_num',data=CI, hue='Income',join=False,palette="Set2",ci="sd")
plt.xticks(rotation=90)
plt.show()

# %%
# Checking the pairwise relation in the dataset.
sns.pairplot(CI,hue="Income",palette="husl")

# %%
CI.head()
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income  \
# 0             0             0              13   United-States   <=50K
# 1             0             0              40   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40            Cuba   <=50K
# 4             0             0              40   United-States   <=50K
#
#   age_group
# 0     41-50
# 1     31-40
# 2     51-60
# 3     19-30
# 4     31-40

# %% [markdown]
# # Encoding categorical data

# %%
# Using Label Encoder on categorical variable
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in Category:
    CI[i] = le.fit_transform(CI[i])
CI.head()
# Out:
#    Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0   50          5   83311          9             13               2
# 1   38          3  215646         11              9               0
# 2   53          3  234721          1              7               2
# 3   28          3  338409          9             13               2
# 4   37          3  284582         12             14               2
#
#    Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0           3             0     4    1             0             0
# 1           5             1     4    1             0             0
# 2           5             0     2    1             0             0
# 3           9             5     2    0             0             0
# 4           3             5     4    0             0             0
#
#    Hours_per_week  Native_country  Income age_group
# 0              13              38       0     41-50
# 1              40              38       0     31-40
# 2              40              38       0     51-60
# 3              40               4       0     19-30
# 4              40              38       0     31-40

# %% [markdown]
# # Feature selection and Engineering

# %% [markdown]
# Outliers Detection and Removal

# %%
plt.figure(figsize=(18,10),facecolor='white')
plotnumber=1

for column in Numerical:
    if plotnumber<=6:
        ax=plt.subplot(2,3,plotnumber)
        sns.boxplot(CI[column],color='g')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
# Droping unnecessary columns
CI.drop(["Fnlwgt", "Education"], axis=1, inplace=True)

# %% [markdown]
# Outliers removal using Zscore method

# %%
from scipy.stats import zscore
z = np.abs(zscore(CI))
threshold = 3
CI1 = CI[(z<3).all(axis = 1)]

print ("Shape of the dataframe before removing outliers: ", CI.shape)
print ("Shape of the dataframe after removing outliers: ", CI1.shape)
print ("Percentage of data loss post outlier removal: ", (CI.shape[0]-CI1.shape[0])/CI.shape[0]*100)

CI=CI1.copy() # reassigning the changed dataframe name to our original dataframe name

# %%
print("\033[1m"+'Percentage Data Loss :'+"\033[0m",((32536-28061)/32536)*100,'%')

# %% [markdown]
# Skewness of features

# %%
plt.figure(figsize=(22,5),facecolor='white')
plotnum=1
for col in CI[['Age','Capital_gain','Capital_loss','Hours_per_week']]:
    if plotnum<=4:
        plt.subplot(1,4,plotnum)
        sns.distplot(CI[col],color='r')
        plt.xlabel(col,fontsize=20)
    plotnum+=1
plt.show()

# %%
CI.skew()

# %% [markdown]
# Corrleation

# %%
CI.corr()
# Out:
#                      Age  Workclass  Education_num  Marital_status  \
# Age             1.000000   0.040463       0.036224       -0.266142
# Workclass       0.040463   1.000000       0.003412       -0.020506
# Education_num   0.036224   0.003412       1.000000       -0.069196
# Marital_status -0.266142  -0.020506      -0.069196        1.000000
# Occupation      0.001756   0.007285       0.070965        0.034901
# Relationship   -0.263744  -0.057904      -0.094424        0.185542
# Race            0.029116   0.048322       0.031998       -0.067942
# Sex             0.088708   0.071522       0.012181       -0.129425
# Capital_gain    0.077676   0.031497       0.122661       -0.043373
# Capital_loss    0.057745   0.002661       0.079901       -0.034134
# Hours_per_week  0.068515   0.042208       0.148426       -0.190433
# Native_country -0.000659  -0.001691       0.088044       -0.020892
# Income          0.234039   0.002747       0.335299       -0.199187
#
#                 Occupation  Relationship      Race       Sex  Capital_gain  \
# Age               0.001756     -0.263744  0.029116  0.088708      0.077676
# Workclass         0.007285     -0.057904  0.048322  0.071522      0.031497
# Education_num     0.070965     -0.094424  0.031998  0.012181      0.122661
# Marital_status    0.034901      0.185542 -0.067942 -0.129425     -0.043373
# Occupation        1.000000     -0.037443 -0.004789  0.047683      0.018013
# Relationship     -0.037443      1.000000 -0.116048 -0.582593     -0.057945
# Race             -0.004789     -0.116048  1.000000  0.087464      0.011152
# Sex               0.047683     -0.582593  0.087464  1.000000      0.048486
# Capital_gain      0.018013     -0.057945  0.011152  0.048486      1.000000
# Capital_loss      0.009644     -0.061100  0.018916  0.045576     -0.031638
# Hours_per_week   -0.012851     -0.248876  0.041921  0.229190      0.078408
# Native_country   -0.002124     -0.010838  0.116848  0.001745      0.008776
# Income            0.034490     -0.250955  0.071855  0.215984      0.223340
#
#                 Capital_loss  Hours_per_week  Native_country    Income
# Age                 0.057745        0.068515       -0.000659  0.234039
# Workclass           0.002661        0.042208       -0.001691  0.002747
# Education_num       0.079901        0.148426        0.088044  0.335299
# Marital_status     -0.034134       -0.190433       -0.020892 -0.199187
# Occupation          0.009644       -0.012851       -0.002124  0.034490
# Relationship       -0.061100       -0.248876       -0.010838 -0.250955
# Race                0.018916        0.041921        0.116848  0.071855
# Sex                 0.045576        0.229190        0.001745  0.215984
# Capital_gain       -0.031638        0.078408        0.008776  0.223340
# Capital_loss        1.000000        0.054229        0.009337  0.150498
# Hours_per_week      0.054229        1.000000        0.006802  0.229659
# Native_country      0.009337        0.006802        1.000000  0.022858
# Income              0.150498        0.229659        0.022858  1.000000

# %%
plt.figure(figsize=(25,15))
sns.heatmap(CI.corr(), vmin=-1, vmax=1, annot=True, square=True, fmt='0.3f', 
            annot_kws={'size':10}, cmap="gist_stern")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
plt.figure(figsize = (18,6))
CI.corr()['Income'].drop(['Income']).sort_values(ascending=False).plot(kind='bar',color = 'purple')
plt.xlabel('Features',fontsize=15)
plt.ylabel('Income',fontsize=15)
plt.title('Correlation of features with Target Variable Income',fontsize = 18)
plt.show()

# %% [markdown]
# # Balanceing Imbalanced target feature

# %%
CI.Income.value_counts()
# Out:
# 0    24697
# 1     7839
# Name: Income, dtype: int64

# %% [markdown]
# Balancing using SMOTE

# %%
from imblearn.over_sampling import SMOTE

# %%
# Splitting data in target and dependent feature
X = CI.drop(['Income'], axis =1)
Y = CI['Income']

# %%
# Oversampleing using SMOTE Techniques
oversample = SMOTE()
X, Y = oversample.fit_resample(X, Y)

# %%
Y.value_counts()
# Out:
# 0    24697
# 1     7839
# Name: Income, dtype: int64

# %% [markdown]
# Standard Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scale = scaler.fit_transform(X)

# %%
from sklearn.decomposition import PCA
pca = PCA()
#plot the graph to find the principal components
x_pca = pca.fit_transform(X_scale)
plt.figure(figsize=(10,10))
plt.plot(np.cumsum(pca.explained_variance_ratio_), 'ro-')
plt.xlabel('Number of Components')
plt.ylabel('Variance %')
plt.title('Explained variance Ratio')
plt.grid()

# %%
pca_new = PCA(n_components=9)
x_new = pca_new.fit_transform(X_scale)

# %%
principle_x=pd.DataFrame(x_new,columns=np.arange(9))

# %% [markdown]
# # Machine Learning Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=99, test_size=.3)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)

# %% [markdown]
# Finding best Random state

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score
maxAccu=0
maxRS=0
for i in range(1,250):
    X_train,X_test,Y_train,Y_test = train_test_split(principle_x,Y,test_size = 0.3, random_state=i)
    log_reg=LogisticRegression()
    log_reg.fit(X_train,Y_train)
    y_pred=log_reg.predict(X_test)
    acc=accuracy_score(Y_test,y_pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Best accuracy is', maxAccu ,'on Random_state', maxRS)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=28, test_size=.3)
log_reg=LogisticRegression()
log_reg.fit(X_train,Y_train)
y_pred=log_reg.predict(X_test)
print('\033[1m'+'Logistics Regression Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of Logistics Regression :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Logistics Regression :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of Logistics Regression'+'\033[0m \n',classification_report(Y_test, y_pred))

# %% [markdown]
# Finding Optimal value of n_neighbors for KNN

# %%
from sklearn import neighbors
from math import sqrt
from sklearn.metrics import mean_squared_error
rmse_val = [] #to store rmse values for different k
for K in range(12):
    K = K+1
    model = neighbors.KNeighborsClassifier(n_neighbors = K)

    model.fit(X_train,Y_train)  #fit the model
    y_pred=model.predict(X_test) #make prediction on test set
    error = sqrt(mean_squared_error(Y_test,y_pred)) #calculate rmse
    rmse_val.append(error) #store rmse values
    print('RMSE value for k= ' , K , 'is:', error)

# %%
#plotting the rmse values against k values -
plt.figure(figsize = (8,6))
plt.plot(range(12), rmse_val, color='blue', linestyle='dashed', marker='o', markerfacecolor='green', markersize=10)

# %%
model=[ LogisticRegression(),
        SVC(),
        GaussianNB(),
        DecisionTreeClassifier(),
        KNeighborsClassifier(n_neighbors = 3),
        RandomForestClassifier(),
        ExtraTreesClassifier()]

# %%
for m in model:
    m.fit(X_train,Y_train)
    y_pred=m.predict(X_test)
    print('\033[1m'+'Classification ML Algorithm Evaluation Matrix',m,'is' +'\033[0m')
    print('\n')
    print('\033[1m'+'Accuracy Score :'+'\033[0m\n', accuracy_score(Y_test, y_pred))
    print('\n')
    print('\033[1m'+'Confusion matrix :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
    print('\n')
    print('\033[1m'+'Classification Report :'+'\033[0m \n',classification_report(Y_test, y_pred))
    print('\n')
    print('============================================================================================================')

# %% [markdown]
# # CrossValidation :

# %%
from sklearn.model_selection import cross_val_score
model=[LogisticRegression(),
        SVC(),
        GaussianNB(),
        DecisionTreeClassifier(),
        KNeighborsClassifier(n_neighbors = 3),
        RandomForestClassifier(),
        ExtraTreesClassifier()]

for m in model:
    score = cross_val_score(m, principle_x, Y, cv =5)
    print('\n')
    print('\033[1m'+'Cross Validation Score', m, ':'+'\033[0m\n')
    print("Score :" ,score)
    print("Mean Score :",score.mean())
    print("Std deviation :",score.std())
    print('\n')
    print('============================================================================================================')

# %% [markdown]
# # Hyper Parameter Tuning : GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter= {'criterion' : ['gini', 'entropy'],
              'min_samples_split':[3,5,8],
              'max_depth' : [20,30,40],
              'n_estimators' : [100, 150, 200]
             }

# %%
GCV = GridSearchCV(ExtraTreesClassifier(),parameter,verbose=10)
GCV.fit(X_train,Y_train)

# %%
GCV.best_params_

# %% [markdown]
# Final Model

# %%
Final_mod = ExtraTreesClassifier(criterion='entropy',n_estimators= 200, max_depth=30 ,min_samples_split= 8)
Final_mod.fit(X_train,Y_train)
y_pred=Final_mod.predict(X_test)
print('\033[1m'+'Accuracy Score :'+'\033[0m\n', accuracy_score(Y_test, y_pred))

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import plot_roc_curve
disp = plot_roc_curve(Final_mod,X_test,Y_test)   
plt.legend(prop={'size':11}, loc='lower right')
plt.figure(figsize=(10,10))
plt.show()
plt.show()
auc_score = roc_auc_score(Y_test, Final_mod.predict(X_test))
print('\033[1m'+'Auc Score :'+'\033[0m\n',auc_score)

# %% [markdown]
# # Saving model

# %%
import joblib
joblib.dump(Final_mod,'Census_Income_Final.pkl')
# Out:
# ['Census_Income_Final.pkl']
