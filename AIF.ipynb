# %%
import pandas as pd # for data wrangling purpose
import numpy as np # Basic computation library
import seaborn as sns # For Visualization 
import matplotlib.pyplot as plt # ploting package
# %matplotlib inline
import warnings # Filtering warnings
warnings.filterwarnings('ignore')

# %%
AI=pd.read_csv('Automobile_insurance_fraud.csv')

# %%
AI
# Out:
#      328  48  521585  17-10-2014  OH   250/500  1000  1406.91        0  \
# 0    228  42  342868  27-06-2006  IN   250/500  2000  1197.22  5000000
# 1    134  29  687698  06-09-2000  OH   100/300  2000  1413.14  5000000
# 2    256  41  227811  25-05-1990  IL   250/500  2000  1415.74  6000000
# 3    228  44  367455  06-06-2014  IL  500/1000  1000  1583.91  6000000
# 4    256  39  104594  12-10-2006  OH   250/500  1000  1351.10        0
# ..   ...  ..     ...         ...  ..       ...   ...      ...      ...
# 994    3  38  941851  16-07-1991  OH  500/1000  1000  1310.80        0
# 995  285  41  186934  05-01-2014  IL   100/300  1000  1436.79        0
# 996  130  34  918516  17-02-2003  OH   250/500   500  1383.49  3000000
# 997  458  62  533940  18-11-2011  IL  500/1000  2000  1356.92  5000000
# 998  456  60  556080  11-11-1996  OH   250/500  1000   766.19        0
#
#      466132  ...  2 YES.1   71610   6510  13020  52080        Saab      92x  \
# 0    468176  ...  0     ?    5070    780    780   3510    Mercedes     E400
# 1    430632  ...  3    NO   34650   7700   3850  23100       Dodge      RAM
# 2    608117  ...  2    NO   63400   6340   6340  50720   Chevrolet    Tahoe
# 3    610706  ...  1    NO    6500   1300    650   4550      Accura      RSX
# 4    478456  ...  2    NO   64100   6410   6410  51280        Saab       95
# ..      ...  ... ..   ...     ...    ...    ...    ...         ...      ...
# 994  431289  ...  1     ?   87200  17440   8720  61040       Honda   Accord
# 995  608177  ...  3     ?  108480  18080  18080  72320  Volkswagen   Passat
# 996  442797  ...  3   YES   67500   7500   7500  52500      Suburu  Impreza
# 997  441714  ...  1   YES   46980   5220   5220  36540        Audi       A5
# 998  612260  ...  3     ?    5060    460    920   3680    Mercedes     E400
#
#      2004  Y
# 0    2007  Y
# 1    2007  N
# 2    2014  Y
# 3    2009  N
# 4    2003  Y
# ..    ... ..
# 994  2006  N
# 995  2015  N
# 996  1996  N
# 997  1998  N
# 998  2007  N
#
# [999 rows x 39 columns]

# %%
file_path=r"Automobile_insurance_fraud.csv"
AI1=pd.read_csv(file_path,header=None,names=['months_as_customer', 'age', 'policy_number', 'policy_deductable', 'umbrella_limit', 'insured_zip', 'capital-gains', 'capital-loss', 'incident_hour_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries', 'witnesses', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'auto_year','policy_annual_premium', '_c39','policy_bind_date', 'policy_state', 'policy_csl', 'insured_sex', 'insured_education_level', 'insured_occupation', 'insured_hobbies', 'insured_relationship', 'incident_date', 'incident_type', 'collision_type', 'incident_severity', 'authorities_contacted', 'incident_state', 'incident_city', 'incident_location', 'property_damage', 'police_report_available', 'auto_make', 'auto_model', 'fraud_reported'])

# %%
print('No of Rows:',AI1.shape[0])
print('No of Columns:',AI1.shape[1])
pd.set_option('display.max_columns', None) # This will enable us to see truncated columns
AI1.head()
# Out:
# No of Rows: 1000
# No of Columns: 40
#    months_as_customer  age  policy_number policy_deductable umbrella_limit  \
# 0                 328   48         521585        17-10-2014             OH
# 1                 228   42         342868        27-06-2006             IN
# 2                 134   29         687698        06-09-2000             OH
# 3                 256   41         227811        25-05-1990             IL
# 4                 228   44         367455        06-06-2014             IL
#
#   insured_zip  capital-gains  capital-loss  incident_hour_of_the_day  \
# 0     250/500           1000       1406.91                         0
# 1     250/500           2000       1197.22                   5000000
# 2     100/300           2000       1413.14                   5000000
# 3     250/500           2000       1415.74                   6000000
# 4    500/1000           1000       1583.91                   6000000
#
#    number_of_vehicles_involved bodily_injuries  witnesses total_claim_amount  \
# 0                       466132            MALE         MD       craft-repair
# 1                       468176            MALE         MD  machine-op-inspct
# 2                       430632          FEMALE        PhD              sales
# 3                       608117          FEMALE        PhD       armed-forces
# 4                       610706            MALE  Associate              sales
#
#   injury_claim  property_claim  vehicle_claim  auto_year  \
# 0     sleeping         husband          53300          0
# 1      reading  other-relative              0          0
# 2  board-games       own-child          35100          0
# 3  board-games       unmarried          48900     -62400
# 4  board-games       unmarried          66000     -46000
#
#   policy_annual_premium                      _c39 policy_bind_date  \
# 0            25-01-2015  Single Vehicle Collision   Side Collision
# 1            21-01-2015             Vehicle Theft                ?
# 2            22-02-2015   Multi-vehicle Collision   Rear Collision
# 3            10-01-2015  Single Vehicle Collision  Front Collision
# 4            17-02-2015             Vehicle Theft                ?
#
#    policy_state policy_csl insured_sex insured_education_level  \
# 0  Major Damage     Police          SC                Columbus
# 1  Minor Damage     Police          VA               Riverwood
# 2  Minor Damage     Police          NY                Columbus
# 3  Major Damage     Police          OH               Arlington
# 4  Minor Damage       None          NY               Arlington
#
#   insured_occupation  insured_hobbies  insured_relationship incident_date  \
# 0     9935 4th Drive                5                     1           YES
# 1       6608 MLK Hwy                8                     1             ?
# 2  7121 Francis Lane                7                     3            NO
# 3   6956 Maple Drive                5                     1             ?
# 4       3041 3rd Ave               20                     1            NO
#
#    incident_type  collision_type incident_severity  authorities_contacted  \
# 0              1               2               YES                  71610
# 1              0               0                 ?                   5070
# 2              2               3                NO                  34650
# 3              1               2                NO                  63400
# 4              0               1                NO                   6500
#
#    incident_state  incident_city  incident_location property_damage  \
# 0            6510          13020              52080            Saab
# 1             780            780               3510        Mercedes
# 2            7700           3850              23100           Dodge
# 3            6340           6340              50720       Chevrolet
# 4            1300            650               4550          Accura
#
#   police_report_available  auto_make auto_model  fraud_reported
# 0                     92x       2004          Y             NaN
# 1                    E400       2007          Y             NaN
# 2                     RAM       2007          N             NaN
# 3                   Tahoe       2014          Y             NaN
# 4                     RSX       2009          N             NaN

# %%
# Sort columns by datatypes
AI1.columns.to_series().groupby(AI1.dtypes).groups
# Out:
# {int64: ['months_as_customer', 'age', 'policy_number', 'capital-gains', 'incident_hour_of_the_day', 'number_of_vehicles_involved', 'vehicle_claim', 'auto_year', 'insured_hobbies', 'insured_relationship', 'incident_type', 'collision_type', 'authorities_contacted', 'incident_state', 'incident_city', 'incident_location', 'auto_make'], float64: ['capital-loss', 'fraud_reported'], object: ['policy_deductable', 'umbrella_limit', 'insured_zip', 'bodily_injuries', 'witnesses', 'total_claim_amount', 'injury_claim', 'property_claim', 'policy_annual_premium', '_c39', 'policy_bind_date', 'policy_state', 'policy_csl', 'insured_sex', 'insured_education_level', 'insured_occupation', 'incident_date', 'incident_severity', 'property_damage', 'police_report_available', 'auto_model']}

# %% [markdown]
# # Statistical Analysis

# %%
AI1.duplicated('policy_number').sum()
# Out:
# 0

# %%
AI1.isin([' ','NA','-']).sum().any()
# Out:
# False

# %%
AI1.isin(['?']).sum().any()
# Out:
# True

# %% [markdown]
# Let replace '?' with np.NaN

# %%
AI1=AI1.replace('?',np.NaN)

# %% [markdown]
# # Missing value check

# %%
#Finding what percentage of data is missing from the dataset
missing_values = AI1.isnull().sum().sort_values(ascending = False)
percentage_missing_values =(missing_values/len(AI1))*100
print(pd.concat([missing_values, percentage_missing_values], axis =1, keys =['Missing Values', '% Missing data']))
# Out:
#                              Missing Values  % Missing data
# fraud_reported                         1000           100.0
# incident_date                           360            36.0
# incident_severity                       343            34.3
# policy_bind_date                        178            17.8
# incident_type                             0             0.0
# insured_sex                               0             0.0
# insured_education_level                   0             0.0
# insured_occupation                        0             0.0
# insured_hobbies                           0             0.0
# insured_relationship                      0             0.0
# auto_model                                0             0.0
# auto_make                                 0             0.0
# police_report_available                   0             0.0
# policy_csl                                0             0.0
# authorities_contacted                     0             0.0
# incident_state                            0             0.0
# incident_city                             0             0.0
# incident_location                         0             0.0
# property_damage                           0             0.0
# collision_type                            0             0.0
# months_as_customer                        0             0.0
# age                                       0             0.0
# number_of_vehicles_involved               0             0.0
# policy_number                             0             0.0
# policy_deductable                         0             0.0
# umbrella_limit                            0             0.0
# insured_zip                               0             0.0
# capital-gains                             0             0.0
# capital-loss                              0             0.0
# incident_hour_of_the_day                  0             0.0
# bodily_injuries                           0             0.0
# _c39                                      0             0.0
# witnesses                                 0             0.0
# total_claim_amount                        0             0.0
# injury_claim                              0             0.0
# property_claim                            0             0.0
# vehicle_claim                             0             0.0
# auto_year                                 0             0.0
# policy_annual_premium                     0             0.0
# policy_state                              0             0.0

# %%
AI1['property_damage'].fillna(AI1['property_damage'].mode()[0],inplace=True)
AI1['police_report_available'].fillna(AI1['police_report_available'].mode()[0],inplace=True)
AI1['collision_type'].fillna(AI1['collision_type'].mode()[0],inplace=True)

# %%
# Droping unnecessary columns
AI1.drop(['_c39','incident_location','insured_zip','policy_number'],axis=1,inplace=True)

# %%
# Heatmap of missing value
sns.heatmap(AI1.isnull(),cmap="gist_earth")
plt.show()

# %%
# Spliting and extracting policy_csl at '/'
AI1['CSL_Personal']=AI1.policy_csl.str.split('/',expand=True)[0]

# %%
# Now we can drop policy_csl column 
AI1.drop("policy_csl",axis=1,inplace=True)

# %%
# Converting Date columns from object type into datetime data type
AI1['policy_bind_date']=pd.to_datetime(AI1['policy_bind_date'])
AI1['incident_date']=pd.to_datetime(AI1['incident_date'])

# %%
# Extracting Day, Month and Year column from policy_bind_date
AI1['policy_bind_day'] = AI1['policy_bind_date'].dt.day
AI1['policy_bind_month'] = AI1['policy_bind_date'].dt.month
AI1['policy_bind_year'] = AI1['policy_bind_date'].dt.year

# %%
# Since Extraction is done now we can Drop policy_bind_date and incident_date columns
AI1.drop(['policy_bind_date','incident_date'],axis=1,inplace=True)

# %%
# Incident year for all data is 2015 so we gone drop it.
AI1.drop(['incident_year'],axis=1,inplace=True)

# %%
# Lets extract age of the vehicle from auto_year by subtracting it from the year 2018
AI1['Automobile_Age']=2015 - AI1['auto_year']
# Droping auto year column
AI1.drop("auto_year",axis=1,inplace=True)

# %%
Category = ['policy_state',  'insured_sex', 'insured_education_level', 'insured_occupation', 
            'insured_hobbies', 'insured_relationship', 'incident_type', 'collision_type', 'incident_severity',
            'authorities_contacted','incident_state', 'incident_city', 'property_damage','police_report_available',
            'auto_make','auto_model', 'fraud_reported']
    
Numerical = ['months_as_customer','CSL_Personal','CSL_Accidental', 'age', 'policy_deductable', 'umbrella_limit', 'capital-gains', 'capital-loss', 
             'incident_hour_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries', 'witnesses', 
             'total_claim_amount','injury_claim', 'property_claim', 'vehicle_claim', 'Automobile_Age','policy_annual_premium']

# %%
AI1.columns.to_series().groupby(AI1.dtypes).groups
# Out:
# {int64: ['months_as_customer', 'age', 'capital-gains', 'incident_hour_of_the_day', 'number_of_vehicles_involved', 'vehicle_claim', 'auto_year', 'insured_hobbies', 'insured_relationship', 'incident_type', 'collision_type', 'authorities_contacted', 'incident_state', 'incident_city', 'auto_make'], float64: ['capital-loss', 'fraud_reported'], object: ['policy_deductable', 'umbrella_limit', 'bodily_injuries', 'witnesses', 'total_claim_amount', 'injury_claim', 'property_claim', 'policy_annual_premium', 'policy_bind_date', 'policy_state', 'insured_sex', 'insured_education_level', 'insured_occupation', 'incident_date', 'incident_severity', 'property_damage', 'police_report_available', 'auto_model', 'CSL_Personal']}

# %% [markdown]
# Statistical Matrix

# %%
AI1.describe().T.style.background_gradient(subset=['mean','std','50%','count'], cmap='RdPu')
# Out:
# <style  type="text/css" >
# #T_35023_row0_col0,#T_35023_row1_col0,#T_35023_row2_col0,#T_35023_row3_col0,#T_35023_row4_col0,#T_35023_row4_col1,#T_35023_row4_col2,#T_35023_row5_col0,#T_35023_row5_col5,#T_35023_row6_col0,#T_35023_row7_col0,#T_35023_row8_col0,#T_35023_row9_col0,#T_35023_row10_col0,#T_35023_row11_col0,#T_35023_row12_col0,#T_35023_row13_col0,#T_35023_row14_col0,#T_35023_row15_col0{
#             background-color:  #49006a;
#             color:  #f1f1f1;
#         }#T_35023_row0_col1,#T_35023_row1_col1,#T_35023_row2_col1,#T_35023_row3_col1,#T_35023_row8_col1,#T_35023_row9_col1,#T_35023_row10_col1,#T_35023_row11_col1,#T_35023_row15_col1{
#             background-color:  #fff3ef;
#             color:  #000000;
#         }#T_35023_row0_col2,#T_35023_row1_col2,#T_35023_row2_col2,#T_35023_row3_col2,#T_35023_row7_col1,#T_35023_row7_col5,#T_35023_row8_col2,#T_35023_row9_col2,#T_35023_row10_col2,#T_35023_row11_col2,#T_35023_row13_col2,#T_35023_row14_col2,#T_35023_row15_col2,#T_35023_row16_col0{
#             background-color:  #fff7f3;
#             color:  #000000;
#         }#T_35023_row0_col5,#T_35023_row1_col5,#T_35023_row2_col5,#T_35023_row3_col5,#T_35023_row4_col5,#T_35023_row6_col5,#T_35023_row8_col5,#T_35023_row9_col5,#T_35023_row10_col5,#T_35023_row11_col5{
#             background-color:  #feeeeb;
#             color:  #000000;
#         }#T_35023_row5_col1{
#             background-color:  #f877a6;
#             color:  #000000;
#         }#T_35023_row5_col2,#T_35023_row13_col1,#T_35023_row14_col1{
#             background-color:  #fff2ee;
#             color:  #000000;
#         }#T_35023_row6_col1{
#             background-color:  #feefeb;
#             color:  #000000;
#         }#T_35023_row6_col2,#T_35023_row7_col2{
#             background-color:  #fff5f1;
#             color:  #000000;
#         }#T_35023_row12_col1{
#             background-color:  #feeae7;
#             color:  #000000;
#         }#T_35023_row12_col2{
#             background-color:  #fff6f2;
#             color:  #000000;
#         }#T_35023_row12_col5{
#             background-color:  #fdd7d4;
#             color:  #000000;
#         }#T_35023_row13_col5,#T_35023_row14_col5{
#             background-color:  #feece9;
#             color:  #000000;
#         }#T_35023_row15_col5{
#             background-color:  #feeeea;
#             color:  #000000;
#         }#T_35023_row16_col1,#T_35023_row16_col2,#T_35023_row16_col5{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }</style><table id="T_35023_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >mean</th>        <th class="col_heading level0 col2" >std</th>        <th class="col_heading level0 col3" >min</th>        <th class="col_heading level0 col4" >25%</th>        <th class="col_heading level0 col5" >50%</th>        <th class="col_heading level0 col6" >75%</th>        <th class="col_heading level0 col7" >max</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_35023_level0_row0" class="row_heading level0 row0" >months_as_customer</th>
#                         <td id="T_35023_row0_col0" class="data row0 col0" >1000.000000</td>
#                         <td id="T_35023_row0_col1" class="data row0 col1" >203.954000</td>
#                         <td id="T_35023_row0_col2" class="data row0 col2" >115.113174</td>
#                         <td id="T_35023_row0_col3" class="data row0 col3" >0.000000</td>
#                         <td id="T_35023_row0_col4" class="data row0 col4" >115.750000</td>
#                         <td id="T_35023_row0_col5" class="data row0 col5" >199.500000</td>
#                         <td id="T_35023_row0_col6" class="data row0 col6" >276.250000</td>
#                         <td id="T_35023_row0_col7" class="data row0 col7" >479.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_35023_level0_row1" class="row_heading level0 row1" >age</th>
#                         <td id="T_35023_row1_col0" class="data row1 col0" >1000.000000</td>
#                         <td id="T_35023_row1_col1" class="data row1 col1" >38.948000</td>
#                         <td id="T_35023_row1_col2" class="data row1 col2" >9.140287</td>
#                         <td id="T_35023_row1_col3" class="data row1 col3" >19.000000</td>
#                         <td id="T_35023_row1_col4" class="data row1 col4" >32.000000</td>
#                         <td id="T_35023_row1_col5" class="data row1 col5" >38.000000</td>
#                         <td id="T_35023_row1_col6" class="data row1 col6" >44.000000</td>
#                         <td id="T_35023_row1_col7" class="data row1 col7" >64.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_
>3.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_29813_level0_row4" class="row_heading level0 row4" >authorities_contacted</th>
#                         <td id="T_29813_row4_col0" class="data row4 col0" >1000.000000</td>
#                         <td id="T_29813_row4_col1" class="data row4 col1" >52761.940000</td>
#                         <td id="T_29813_row4_col2" class="data row4 col2" >26401.533190</td>
#                         <td id="T_29813_row4_col3" class="data row4 col3" >100.000000</td>
#                         <td id="T_29813_row4_col4" class="data row4 col4" >41812.500000</td>
#                         <td id="T_29813_row4_col5" class="data row4 col5" >58055.000000</td>
#                         <td id="T_29813_row4_col6" class="data row4 col6" >70592.500000</td>
#                         <td id="T_29813_row4_col7" class="data row4 col7" >114920.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_29813_level0_row5" class="row_heading level0 row5" >incident_state</th>
#                         <td id="T_29813_row5_col0" class="data row5 col0" >1000.000000</td>
#                         <td id="T_29813_row5_col1" class="data row5 col1" >7433.420000</td>

# %%
for i in Category:
    print(i)
    print(AI1[i].value_counts())
    print("="*100)
# Out:
# policy_state
# Minor Damage      354
# Total Loss        280
# Major Damage      276
# Trivial Damage     90
# Name: policy_state, dtype: int64
# ====================================================================================================
# insured_sex
# NY    262
# SC    248
# WV    217
# VA    110
# NC    110
# PA     30
# OH     23
# Name: insured_sex, dtype: int64
# ====================================================================================================
# insured_education_level
# Springfield    157
# Arlington      152
# Columbus       149
# Northbend      145
# Hillsdale      141
# Riverwood      134
# Northbrook     122
# Name: insured_education_level, dtype: int64
# ====================================================================================================
# insured_occupation
# 4176 Britain Hwy      1
# 8655 Cherokee Lane    1
# 3929 Elm Ave          1
# 7042 Maple Ridge      1
# 7819 2nd Ave          1
#                      ..
# 3878 Tree Lane        1
# 1328 Texas Lane       1
# 6044 Weaver Drive     1
# 1699 Oak Drive        1
# 9224 Sky Drive        1
# Name: insured_occupation, Length: 1000, dtype: int64
# ====================================================================================================
# insured_hobbies
# 17    54
# 3     53
# 0     52
# 23    51
# 16    49
# 4     46
# 10    46
# 13    46
# 6     44
# 14    43
# 9     43
# 21    42
# 18    41
# 7     40
# 19    40
# 12    40
# 15    39
# 22    38
# 8     36
# 20    34
# 5     33
# 2     31
# 11    30
# 1     29
# Name: insured_hobbies, dtype: int64
# ====================================================================================================
# insured_relationship
# 1    581
# 3    358
# 4     31
# 2     30
# Name: insured_relationship, dtype: int64
# ====================================================================================================
# incident_type
# 0    340
# 2    332
# 1    328
# Name: incident_type, dtype: int64
# ====================================================================================================
# collision_type
# 1    258
# 2    250
# 0    249
# 3    243
# Name: collision_type, dtype: int64
# ====================================================================================================
# incident_severity
# NO     343
# YES    314
# Name: incident_severity, dtype: int64
# ====================================================================================================
# authorities_contacted
# 59400    5
# 2640     4
# 75400    4
# 60600    4
# 5940     4
#         ..
# 51590    1
# 31700    1
# 53640    1
# 63100    1
# 88920    1
# Name: authorities_contacted, Length: 763, dtype: int64
# ====================================================================================================
# incident_state
# 0        25
# 640       7
# 480       7
# 1180      5
# 860       5
#          ..
# 10800     1
# 12580     1
# 6700      1
# 4650      1
# 16500     1
# Name: incident_state, Length: 638, dtype: int64
# ====================================================================================================
# incident_city
# 0        19
# 860       6
# 640       5
# 480       5
# 10000     5
#          ..
# 5350      1
# 6700      1
# 20550     1
# 4650      1
# 11260     1
# Name: incident_city, Length: 626, dtype: int64
# ====================================================================================================
# property_damage
# Dodge         80
# Saab          80
# Suburu        80
# Nissan        78
# Chevrolet     76
# Ford          72
# BMW           72
# Toyota        70
# Audi          69
# Volkswagen    68
# Accura        68
# Jeep          67
# Mercedes      65
# Honda         55
# Name: property_damage, dtype: int64
# ====================================================================================================
# police_report_available
# RAM               43
# Wrangler          42
# A3                37
# Neon              37
# MDX               36
# Jetta             35
# Passat            33
# Legacy            32
# A5                32
# Pathfinder        31
# Malibu            30
# Camry             28
# 92x               28
# Forrestor         28
# F150              27
# 95                27
# E400              27
# 93                25
# Grand Cherokee    25
# Escape            24
# Tahoe             24
# Maxima            24
# X5                23
# Ultima            23
# Silverado         22
# Highlander        22
# Civic             22
# Fusion            21
# Corolla           20
# ML350             20
# TL                20
# Impreza           20
# CRV               20
# C300              18
# 3 Series          18
# X6                16
# M5                15
# Accord            13
# RSX               12
# Name: police_report_available, dtype: int64
# ====================================================================================================
# auto_make
# 1995    56
# 1999    55
# 2005    54
# 2006    53
# 2011    53
# 2007    52
# 2003    51
# 2010    50
# 2009    50
# 2013    49
# 2002    49
# 2015    47
# 1997    46
# 2012    46
# 2008    45
# 2014    44
# 2001    42
# 2000    42
# 1998    40
# 2004    39
# 1996    37
# Name: auto_make, dtype: int64
# ====================================================================================================
# auto_model
# N    753
# Y    247
# Name: auto_model, dtype: int64
# ====================================================================================================
# fraud_reported
# Series([], Name: fraud_reported, dtype: int64)
# ====================================================================================================

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('husl')
f,ax=plt.subplots(1,2,figsize=(14,7))
AI1['fraud_reported'].value_counts().plot.pie(explode=[0,0.1],autopct='%3.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':18}, ax=ax[0],shadow=True)
ax[0].set_title('Fraud Cases Distribution', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')
sns.countplot('fraud_reported',data=AI1,ax=ax[1])
ax[1].set_title('Fraud Cases Count',fontsize=22,fontweight ='bold')
ax[1].set_xlabel("Fraud Cases",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=18,fontweight ='bold')
plt.show()

# %% [markdown]
# Start exploring Target variable

# %% [markdown]
# # Analysing Age vs Fraud

# %%
print('Minimum Age :',AI1.age.min(),'Years')
print('Maximum Age :',AI1.age.max(),'Years')
print('Average Age :',AI1.age.mean(),'Years')
# Out:
# Minimum Age : 19 Years
# Maximum Age : 64 Years
# Average Age : 38.948 Years

# %%
plt.figure(figsize=(7,6))
sns.histplot(AI1.age, kde=True, color='b')
plt.xlabel('Age',fontsize=16)
plt.title('Age Distribution', fontsize=18,fontweight ='bold')
plt.show()

# %%
# Spliting age in different age range
AI1['age_bins'] = pd.cut(AI1.age, bins = [0, 10, 20, 30, 40, 50, 60, 70], 
                          include_lowest = True, labels = ['0-10','11-20','21-30','31-40', '41-50', '51-60', '61-70'])

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=AI1.age_bins, hue=AI1.fraud_reported)
plt.xlabel('Age',fontsize=18,fontweight ='bold')
plt.title('Age Distribution Vs Fraud Cases', fontsize=20,fontweight ='bold')
plt.show()

# %% [markdown]
# Observation:
# Maximum fraud cases comes from people with age group of 31-50 year.
# Very few cases in 60+ year old peoples.

# %% [markdown]
# # Policy State Vs Fraud cases

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('husl')
fig,ax=plt.subplots(1,2,figsize=(16,7))
AI1['policy_state'].value_counts().plot.pie(explode=[0.03,0.03,0.03],autopct='%2.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':13}, ax=ax[0],shadow=True)
ax[0].set_title('Policy-holder State Distribution', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

table = pd.crosstab(AI1['policy_state'], AI1['fraud_reported'])
table.plot(kind = 'bar', ax=ax[1])
ax[1].set_title('Statewise Proportion of Fraud cases',fontsize=20,fontweight ='bold')
ax[1].set_xlabel(" State ",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# Insured Gender VS Fraud cases

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('husl')
fig,ax=plt.subplots(1,2,figsize=(16,7))
AI1['insured_sex'].value_counts().plot.pie(explode=[0.03,0.03],autopct='%2.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':13}, ax=ax[0],shadow=True)
ax[0].set_title('Policy-holder Gender Distribution', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

table = pd.crosstab(AI1['insured_sex'], AI1['fraud_reported'])
table.plot(kind = 'bar', ax=ax[1])
ax[1].set_title('Genderwise Proportion of Fraud cases',fontsize=20,fontweight ='bold')
ax[1].set_xlabel(" Gender ",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# Education_level vs Fraud cases

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('husl')
fig,ax=plt.subplots(1,2,figsize=(16,7))
AI1['insured_education_level'].value_counts().plot.pie(explode=[0.03,0.03,0.03,0.03,0.03,0.03,.03],autopct='%2.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':13}, ax=ax[0],shadow=True)
ax[0].set_title('Policy-holder Education_level Distribution', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

table = pd.crosstab(AI1['insured_education_level'], AI1['fraud_reported'])
table.plot(kind = 'bar', ax=ax[1])
ax[1].set_title('Fraud cases vs Policy-holder Education_level ',fontsize=20,fontweight ='bold')
ax[1].set_xlabel(" Education_level ",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Occupation of Insured Customers

# %%
# let's check the insured occupation
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (11, 8)
sns.countplot(AI1['insured_occupation'], palette = 'gist_earth')
plt.title('Different Types of Occupation of Insured Customers' ,fontsize=20,fontweight ='bold')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Hobbies of Insured Customers

# %%
# let's check the insured hobbies
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (15, 8)
sns.countplot(AI1['insured_hobbies'], palette = 'cool')
plt.title('Different Types of Hobbies of Insured Customers',fontsize=20,fontweight ='bold')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Different Types of Incidents Vs Fraud cases

# %%
# let's check the incident types
plt.rcParams['figure.figsize'] = (10,5)
sns.countplot(AI1['incident_type'], palette = 'Dark2')
plt.title('Different Types of Incidents',fontsize=20,fontweight ='bold')
plt.xlabel('Different Types of Incidents', fontsize=18,fontweight='bold')
plt.ylabel('Population', fontsize=18,fontweight='bold')
plt.xticks(fontweight ='bold')
plt.show()

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('Dark2')
f,ax=plt.subplots(1,2,figsize=(20,11))
AI1['incident_type'].value_counts().plot.pie(explode=[0.03,.03,.03,.03],autopct='%3.1f%%',
                                          textprops ={ 'fontsize':14}, ax=ax[0],shadow=True)
ax[0].set_title('Incident Distribution', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')
sns.countplot('incident_type',data=AI1,ax=ax[1])
ax[1].set_title('Different Types of Incidents',fontsize=20,fontweight ='bold')
ax[1].set_xlabel("incident_type",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,rotation=30,fontweight ='bold')
plt.tight_layout()
plt.show()

# %%
# let's check the insured hobbies
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (12,7)
table = pd.crosstab(AI1['incident_type'], AI1['fraud_reported'])
table.plot(kind = 'bar')
plt.title('Fraud cases As per Incident Type',fontsize=20,fontweight ='bold')
plt.xlabel('Different Incidents', fontsize=16,fontweight='bold')
plt.xticks(fontsize=14,rotation=0,fontweight ='bold')
plt.show()

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('Set2_r')
fig,ax=plt.subplots(1,2,figsize=(16,7))
AI1['collision_type'].value_counts().plot.pie(explode=[0.03,0.03,0.03],autopct='%2.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':13}, ax=ax[0],shadow=True)
ax[0].set_title('Collision Pie Chart', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

table = pd.crosstab(AI1['collision_type'], AI1['fraud_reported'])
table.plot(kind = 'bar', ax=ax[1])
ax[1].set_title('Fraud cases in different Collision Type ',fontsize=20,fontweight ='bold')
ax[1].set_xlabel("Collision Type ",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Exploration of different Collision

# %%
# let's check the insured hobbies
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (13,7)
sns.set_palette('coolwarm')
table = pd.crosstab(AI1['incident_type'], AI1['collision_type'])
(table.div(table.sum(axis=1),axis=0)*100).plot(kind='bar',stacked=True)
plt.title(' Incident Type VS Collision Type',fontsize=20,fontweight ='bold')
plt.xlabel('Collision', fontsize=16,fontweight='bold')
plt.xticks(fontsize=14,rotation=0,fontweight ='bold')
plt.show()

# %% [markdown]
# # Collision VS Incident Severity

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('Set2_r')
fig,ax=plt.subplots(1,2,figsize=(16,7))
AI1['incident_severity'].value_counts().plot.pie(explode=[0.03,0.03,0.03,.03],autopct='%2.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':13}, ax=ax[0],shadow=True)
ax[0].set_title('Severity of Collision Pie Chart', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

table = pd.crosstab(AI1['incident_severity'], AI1['collision_type'])
table.plot(kind = 'bar', ax=ax[1])
ax[1].set_title('Incident Severity vs Collision Type ',fontsize=20,fontweight ='bold')
ax[1].set_xlabel("Collision Type ",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation=0)
plt.tight_layout()
plt.show()

# %%
pd.crosstab(AI1['incident_type'], AI1['incident_severity']).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_9bd9d_row0_col0{
#             background-color:  #b3d966;
#             color:  #000000;
#         }#T_9bd9d_row0_col1,#T_9bd9d_row2_col0{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_9bd9d_row1_col0,#T_9bd9d_row1_col1{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }#T_9bd9d_row2_col1{
#             background-color:  #55aa66;
#             color:  #000000;
#         }</style><table id="T_9bd9d_" ><thead>    <tr>        <th class="index_name level0" >incident_severity</th>        <th class="col_heading level0 col0" >NO</th>        <th class="col_heading level0 col1" >YES</th>    </tr>    <tr>        <th class="index_name level0" >incident_type</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9bd9d_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9bd9d_row0_col0" class="data row0 col0" >113</td>
#                         <td id="T_9bd9d_row0_col1" class="data row0 col1" >103</td>
#             </tr>
#             <tr>
#                         <th id="T_9bd9d_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_9bd9d_row1_col0" class="data row1 col0" >120</td>
#                         <td id="T_9bd9d_row1_col1" class="data row1 col1" >106</td>
#             </tr>
#             <tr>
#                         <th id="T_9bd9d_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_9bd9d_row2_col0" class="data row2 col0" >110</td>
#                         <td id="T_9bd9d_row2_col1" class="data row2 col1" >105</td>
#             </tr>
#     </tbody></table>

# %%
# let's check the insured hobbies
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (13,7)
sns.set_palette('summer_r')
table = pd.crosstab(AI1['incident_type'], AI1['incident_severity'])
(table.div(table.sum(axis=1),axis=0)*100).plot(kind='bar')
plt.title(' Incident Type VS incident_severity',fontsize=20,fontweight ='bold')
plt.xlabel('Collision', fontsize=16,fontweight='bold')
plt.xticks(fontsize=14,rotation=0,fontweight ='bold')
plt.show()

# %%
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (13,7)
sns.boxenplot(AI1['incident_type'], AI1['vehicle_claim'], palette = 'magma')
plt.title('Incident Type vs Vehicle Claim',fontsize=20,fontweight ='bold')
plt.xlabel('Incident Type', fontsize=16,fontweight='bold')
plt.ylabel('Vehicle Claim Amount', fontsize=16,fontweight='bold')
plt.show()

# %%
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (11,7)
sns.stripplot(AI1['property_damage'], AI1['property_claim'], palette = 'bone')
plt.title('Incident Type vs Vehicle Claim',fontsize=20,fontweight ='bold')
plt.xlabel('Property Damage', fontsize=16,fontweight='bold')
plt.ylabel('Property claim', fontsize=16,fontweight='bold')
plt.show()

# %%
# swarm plot
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (11,7)
sns.swarmplot(AI1['policy_state'], AI1['total_claim_amount'], palette = 'copper')
plt.title('Total Claim Amount in Differnt State',fontsize=20,fontweight ='bold')
plt.xlabel('State', fontsize=16,fontweight='bold')
plt.ylabel('Total claim Amount', fontsize=16,fontweight='bold')
plt.show()

# %%
# swarm plot
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (15,9)
sns.boxplot(AI1['auto_make'], AI1['vehicle_claim'], palette = 'summer_r')
plt.title('Vehicle Claim Amount for different Automobile Makers',fontsize=20,fontweight ='bold')
plt.xlabel('Automobile Makers', fontsize=16,fontweight='bold')
plt.ylabel('Vehicle Claim Amount', fontsize=16,fontweight='bold')
plt.show()

# %%
# swarm plot
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (15,9)
sns.scatterplot(AI1['policy_annual_premium'], AI1['total_claim_amount'], hue=AI1.fraud_reported, palette = 'Set1')
plt.title('Total Claim Amount VS Annual Premium',fontsize=20,fontweight ='bold')
plt.xlabel('Policy Annual Premium', fontsize=16,fontweight='bold')
plt.ylabel('Total Claim Amount', fontsize=16,fontweight='bold')
plt.show()

# %%
# swarm plot
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (12,8)
sns.violinplot(AI1['incident_severity'], AI1['total_claim_amount'], hue=AI1.fraud_reported, palette = 'Set1')
plt.title('Incident Severity VS Total Claim Amount',fontsize=20,fontweight ='bold')
plt.xlabel('Incident Severity', fontsize=16,fontweight='bold')
plt.ylabel('Total Claim Amount', fontsize=16,fontweight='bold')
plt.show()

# %%
pd.set_option('display.max_columns', None) # This will enable us to see truncated columns
AI1.head()
# Out:
#    months_as_customer  age policy_deductable umbrella_limit  capital-gains  \
# 0                 328   48        17-10-2014             OH           1000
# 1                 228   42        27-06-2006             IN           2000
# 2                 134   29        06-09-2000             OH           2000
# 3                 256   41        25-05-1990             IL           2000
# 4                 228   44        06-06-2014             IL           1000
#
#    capital-loss  incident_hour_of_the_day  number_of_vehicles_involved  \
# 0       1406.91                         0                       466132
# 1       1197.22                   5000000                       468176
# 2       1413.14                   5000000                       430632
# 3       1415.74                   6000000                       608117
# 4       1583.91                   6000000                       610706
#
#   bodily_injuries  witnesses total_claim_amount injury_claim  property_claim  \
# 0            MALE         MD       craft-repair     sleeping         husband
# 1            MALE         MD  machine-op-inspct      reading  other-relative
# 2          FEMALE        PhD              sales  board-games       own-child
# 3          FEMALE        PhD       armed-forces  board-games       unmarried
# 4            MALE  Associate              sales  board-games       unmarried
#
#    vehicle_claim  auto_year policy_annual_premium policy_bind_date  \
# 0          53300          0            25-01-2015   Side Collision
# 1              0          0            21-01-2015              NaN
# 2          35100          0            22-02-2015   Rear Collision
# 3          48900     -62400            10-01-2015  Front Collision
# 4          66000     -46000            17-02-2015              NaN
#
#    policy_state insured_sex insured_education_level insured_occupation  \
# 0  Major Damage          SC                Columbus     9935 4th Drive
# 1  Minor Damage          VA               Riverwood       6608 MLK Hwy
# 2  Minor Damage          NY                Columbus  7121 Francis Lane
# 3  Major Damage          OH               Arlington   6956 Maple Drive
# 4  Minor Damage          NY               Arlington       3041 3rd Ave
#
#    insured_hobbies  insured_relationship incident_date  incident_type  \
# 0                5                     1           YES              1
# 1                8                     1           NaN              0
# 2                7                     3            NO              2
# 3                5                     1           NaN              1
# 4               20                     1            NO              0
#
#    collision_type incident_severity  authorities_contacted  incident_state  \
# 0               2               YES                  71610            6510
# 1               0               NaN                   5070             780
# 2               3                NO                  34650            7700
# 3               2                NO                  63400            6340
# 4               1                NO                   6500            1300
#
#    incident_city property_damage police_report_available  auto_make  \
# 0          13020            Saab                     92x       2004
# 1            780        Mercedes                    E400       2007
# 2           3850           Dodge                     RAM       2007
# 3           6340       Chevrolet                   Tahoe       2014
# 4            650          Accura                     RSX       2009
#
#   auto_model  fraud_reported CSL_Personal age_bins
# 0          Y             NaN       Police    41-50
# 1          Y             NaN       Police    41-50
# 2          N             NaN       Police    21-30
# 3          Y             NaN       Police    41-50
# 4          N             NaN         None    41-50

# %% [markdown]
# Encoding categorical data

# %%
Category = ['policy_state', 'insured_sex', 'insured_education_level', 'insured_occupation',
            'insured_hobbies', 'insured_relationship', 'incident_type', 'collision_type', 'incident_severity',
            'authorities_contacted', 'incident_state', 'incident_city', 'property_damage', 'police_report_available', 
            'auto_make', 'auto_model', 'fraud_reported', 'CSL_Personal', 'CSL_Accidental']

# %%
# Using Label Encoder on categorical variable
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in Category:
    AI1[i] = le.fit_transform(AI1[i])
AI1.head()

# %%
# Sort columns by datatypes
AI1.columns.to_series().groupby(AI1.dtypes).groups

# %% [markdown]
# # Feature selection and Engineering

# %% [markdown]
# Outliers Detection and Removal

# %%
Numerical = ['months_as_customer', 'age', 'policy_deductable', 'umbrella_limit', 'capital-gains', 'capital-loss',
             'incident_hour_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries', 'witnesses', 
             'total_claim_amount','injury_claim', 'property_claim', 'vehicle_claim', 'policy_bind_day', 
             'policy_bind_month', 'policy_bind_year', 'incident_day', 'incident_month', 'Automobile_Age','policy_annual_premium']

# %%
len(Numerical)
# Out:
# 21

# %%
plt.figure(figsize=(20,30),facecolor='white')
plotnumber=1

for column in Numerical:
    if plotnumber<=21:
        ax=plt.subplot(7,3,plotnumber)
        sns.boxplot(AI1[column],color='g')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# Outliers removal using Zscore method

# %%
from scipy.stats import zscore
z = np.abs(zscore(AI1))
threshold = 3
AI2 = AI1[(z<3).all(axis = 1)]

print ("Shape of the dataframe before removing outliers: ", AI1.shape)
print ("Shape of the dataframe after removing outliers: ", AI2.shape)
print ("Percentage of data loss post outlier removal: ", (AI1.shape[0]-AI2.shape[0])/AI1.shape[0]*100)

AI1=AI2.copy()

# %% [markdown]
# Skewness of features

# %%
plt.figure(figsize=(20,30),facecolor='white')
sns.set_palette('plasma')
plotnum=1
for col in Numerical:
    if plotnum<=21:
        plt.subplot(7,3,plotnum)
        sns.distplot(AI1[col])
        plt.xlabel(col,fontsize=20)
    plotnum+=1
plt.show()

# %%
AI1[Numerical].skew()

# %%
# Making the skew less than or equal to +0.5 and -0.5 for better prediction using yeo-johnson method
skew=['total_claim_amount','vehicle_claim']

# Importing Powertransformer
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')

# Transfroming skew data
AI1[skew] = scaler.fit_transform(AI1[skew].values)

# %%
AI1[skew].skew()
# Out:
# vehicle_claim    0.47885
# dtype: float64

# %% [markdown]
# Corrleation

# %%
AI1.corr()
# Out:
#                              months_as_customer       age  capital-gains  \
# months_as_customer                     1.000000  0.922098       0.026807
# age                                    0.922098  1.000000       0.029188
# capital-gains                          0.026807  0.029188       1.000000
# capital-loss                           0.005018  0.014404      -0.003245
# incident_hour_of_the_day               0.015498  0.018126       0.010870
# number_of_vehicles_involved            0.017895  0.025604       0.004545
# vehicle_claim                          0.006399 -0.007075       0.035212
# auto_year                              0.020209  0.007368      -0.023544
# policy_state                          -0.059581 -0.058439      -0.015711
# insured_sex                            0.005369  0.005770       0.006517
# insured_education_level               -0.000130 -0.002291      -0.045117
# insured_occupation                    -0.013630 -0.011101      -0.009281
# insured_hobbies                        0.070639  0.087161       0.060935
# insured_relationship                   0.014736  0.022102       0.051214
# incident_type                         -0.010162 -0.015679      -0.022765
# collision_type                         0.058383  0.052359       0.066639
# incident_severity                     -0.071746 -0.063040       0.004936
# authorities_contacted                  0.060677  0.071265       0.028859
# incident_state                         0.065310  0.075124       0.033737
# incident_city                          0.036427  0.060450       0.067902
# property_damage                        0.047655  0.030410      -0.035379
# police_report_available                0.004202  0.017343      -0.003268
# auto_make                             -0.000292  0.001354       0.026105
# auto_model                             0.020544  0.012143       0.014817
# fraud_reported                              NaN       NaN            NaN
# CSL_Personal                           0.010021  0.015417      -0.000760
#
#                              capital-loss  incident_hour_of_the_day  \
# months_as_customer               0.005018                  0.015498
# age                              0.014404                  0.018126
# capital-gains                   -0.003245                  0.010870
# capital-loss                     1.000000                 -0.006247
# incident_hour_of_the_day        -0.006247                  1.000000
# number_of_vehicles_involved      0.032354                  0.019671
# vehicle_claim                   -0.013738                 -0.047268
# auto_year                        0.023547                 -0.024056
# policy_state                    -0.011155                  0.009466
# insured_sex                      0.046434                 -0.077492
# insured_education_level          0.048724                  0.013094
# insured_occupation               0.017883                  0.014510
# insured_hobbies                 -0.001578                 -0.023257
# insured_relationship            -0.045991                 -0.021270
# incident_type                    0.026780                  0.022743
# collision_type                   0.002332                 -0.006738
# incident_severity                0.010332                  0.034177
# authorities_contacted            0.004976                 -0.036806
# incident_state                  -0.019388                 -0.048171
# incident_city                   -0.003793                 -0.017343
# property_damage                  0.000045                 -0.004443
# police_report_available         -0.031849                  0.040256
# auto_make                       -0.049226                  0.009893
# capital-loss                            NaN     -0.055191
# incident_hour_of_the_day                NaN      0.029044
# number_of_vehicles_involved             NaN     -0.017548
# vehicle_claim                           NaN     -0.044892
# auto_year                               NaN      0.025192
# policy_state                            NaN      0.164966
# insured_sex                             NaN      0.026542
# insured_education_level                 NaN     -0.003299
# insured_occupation                      NaN      0.063509
# insured_hobbies                         NaN     -0.060955
# insured_relationship                    NaN     -0.081508
# incident_type                           NaN      0.041692
# collision_type                          NaN     -0.003721
# incident_severity                       NaN      0.016557
# authorities_contacted                   NaN     -0.112751
# incident_state                          NaN     -0.134918
# incident_city                           NaN     -0.112499
# property_damage                         NaN     -0.030309
# police_report_available                 NaN      0.017536
# auto_make                               NaN      0.072524
# auto_model                              NaN     -0.045802
# fraud_reported                          NaN           NaN
# CSL_Personal                            NaN      1.000000

# %%
plt.figure(figsize=(30,20))
sns.heatmap(AI1.corr(), vmin=-1, vmax=1, annot=True, square=True, fmt='0.3f', cmap="gist_stern")
plt.show()

# %%
plt.figure(figsize=(22,10))
AI1.corr()['fraud_reported'].sort_values(ascending=False).drop(['fraud_reported']).plot(kind='bar',color='y')
plt.xlabel('Feature',fontsize=14,fontweight='bold')
plt.ylabel('Target',fontsize=14,fontweight='bold')
plt.title('Correlation of features with Target Variable Fraud_reported',fontsize=20,fontweight='bold')
plt.show()

# %% [markdown]
# Balanceing Imbalanced target feature

# %%
AI1.fraud_reported.value_counts()
# Out:
# 0    1000
# Name: fraud_reported, dtype: int64

# %% [markdown]
# Balancing using SMOTE

# %%
from imblearn.over_sampling import SMOTE

# %%
# Splitting data in target and dependent feature
X = AI1.drop(['fraud_reported'], axis =1)
Y = AI1['fraud_reported']

# %%
# Oversampleing using SMOTE Techniques
oversample = SMOTE()
X, Y = oversample.fit_resample(X, Y)

# %%
Y.value_counts()
# Out:
# 0    1000
# Name: fraud_reported, dtype: int64

# %% [markdown]
# Standard Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scale = scaler.fit_transform(X)

# %% [markdown]
# # Checking Multicollinearity between features using variance_inflation_factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(X_scale,i) for i in range(len(X.columns))]
vif["Features"] = X.columns
vif

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA
pca = PCA()
#plot the graph to find the principal components
x_pca = pca.fit_transform(X_scale)
plt.figure(figsize=(10,10))
plt.plot(np.cumsum(pca.explained_variance_ratio_), 'ro-')
plt.xlabel('Number of Components')
plt.ylabel('Variance %')
plt.title('Explained variance Ratio')
plt.grid()

# %%
pca_new = PCA(n_components=28)
x_new = pca_new.fit_transform(X_scale)

# %%
principle_x=pd.DataFrame(x_new,columns=np.arange(28))

# %% [markdown]
# # Machine Learning Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=99, test_size=.3)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)

# %% [markdown]
# Finding best Random state

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score
maxAccu=0
maxRS=0
for i in range(1,250):
    X_train,X_test,Y_train,Y_test = train_test_split(principle_x,Y,test_size = 0.3, random_state=i)
    log_reg=LogisticRegression()
    log_reg.fit(X_train,Y_train)
    y_pred=log_reg.predict(X_test)
    acc=accuracy_score(Y_test,y_pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Best accuracy is', maxAccu ,'on Random_state', maxRS)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=9, test_size=.3)
log_reg=LogisticRegression()
log_reg.fit(X_train,Y_train)
y_pred=log_reg.predict(X_test)
print('\033[1m'+'Logistics Regression Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of Logistics Regression :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Logistics Regression :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of Logistics Regression'+'\033[0m \n',classification_report(Y_test, y_pred))

# %%
from sklearn import neighbors
from math import sqrt
from sklearn.metrics import mean_squared_error
rmse_val = [] #to store rmse values for different k
for K in range(20):
    K = K+1
    model = neighbors.KNeighborsClassifier(n_neighbors = K)

    model.fit(X_train,Y_train)  #fit the model
    y_pred=model.predict(X_test) #make prediction on test set
    error = sqrt(mean_squared_error(Y_test,y_pred)) #calculate rmse
    rmse_val.append(error) #store rmse values
    print('RMSE value for k= ' , K , 'is:', error)

# %%
#plotting the rmse values against k values -
plt.figure(figsize = (8,6))
plt.plot(range(20), rmse_val, color='blue', linestyle='dashed', marker='o', markerfacecolor='green', markersize=10)

# %% [markdown]
# Applying other classification algorithm

# %%
model=[ LogisticRegression(),
        SVC(),
        GaussianNB(),
        DecisionTreeClassifier(),
        KNeighborsClassifier(n_neighbors = 3),
        RandomForestClassifier(),
        ExtraTreesClassifier()]
        
for m in model:
    m.fit(X_train,Y_train)
    y_pred=m.predict(X_test)
    print('\033[1m'+'Classification ML Algorithm Evaluation Matrix',m,'is' +'\033[0m')
    print('\n')
    print('\033[1m'+'Accuracy Score :'+'\033[0m\n', accuracy_score(Y_test, y_pred))
    print('\n')
    print('\033[1m'+'Confusion matrix :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
    print('\n')
    print('\033[1m'+'Classification Report :'+'\033[0m \n',classification_report(Y_test, y_pred))
    print('\n')
    print('============================================================================================================')

# %% [markdown]
# # CrossValidation :

# %%
from sklearn.model_selection import cross_val_score
model=[LogisticRegression(),
        SVC(),
        GaussianNB(),
        DecisionTreeClassifier(),
        KNeighborsClassifier(n_neighbors = 3),
        RandomForestClassifier(),
        ExtraTreesClassifier()]

for m in model:
    score = cross_val_score(m, principle_x, Y, cv =5)
    print('\n')
    print('\033[1m'+'Cross Validation Score', m, ':'+'\033[0m\n')
    print("Score :" ,score)
    print("Mean Score :",score.mean())
    print("Std deviation :",score.std())
    print('\n')
    print('============================================================================================================')

# %% [markdown]
# # Hyper Parameter Tuning : GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter= {'criterion' : ['gini', 'entropy'],
             'max_features':['auto','sqrt','log2'],
              'min_samples_split':[3,5,8,11],
              'max_depth' : [10,20,30],
              'n_estimators' : [100,200,300,400]
             }

# %%
GCV = GridSearchCV(ExtraTreesClassifier(),parameter,verbose=10)
GCV.fit(X_train,Y_train)

# %%
GCV.best_params_

# %% [markdown]
# # Final Model

# %%
Final_mod = ExtraTreesClassifier(criterion='gini',n_estimators= 200, max_depth=30 ,
                                 min_samples_split= 3, max_features= 'log2')
Final_mod.fit(X_train,Y_train)
y_pred=Final_mod.predict(X_test)
print('\033[1m'+'Accuracy Score :'+'\033[0m\n', accuracy_score(Y_test, y_pred))

# %%
# Lets plot confusion matrix for  FinalModel
Matrix = confusion_matrix(Y_test, y_pred)

x_labels = ["NO","YES"]
y_labels = ["NO","YES"]

fig , ax = plt.subplots(figsize=(5,5))
sns.heatmap(cm, annot = True,linewidths=.2, linecolor="black", fmt = ".0f", ax=ax, 
            cmap="plasma", xticklabels = x_labels, yticklabels = y_labels)

plt.xlabel("Predicted Label",fontsize=14,fontweight='bold')
plt.ylabel("True Label",fontsize=14,fontweight='bold')
plt.title('Confusion Matrix for Final Model',fontsize=20,fontweight='bold')
plt.show()

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import plot_roc_curve
disp = plot_roc_curve(Final_mod,X_test,Y_test)   
plt.legend(prop={'size':11}, loc='lower right')
plt.title('AOC ROC Curve of Final Model',fontsize=20,fontweight='bold')
plt.show()
auc_score = roc_auc_score(Y_test, Final_mod.predict(X_test))
print('\033[1m'+'Auc Score :'+'\033[0m\n',auc_score)

# %% [markdown]
# # Saving model

# %%
import joblib
joblib.dump(Final_mod,'Insurance_claims_Final.pkl')

# %% [markdown]
# # Predicting the Final Model

# %%
# Prediction
prediction = Final_mod.predict(X_test)

# %%
Actual = np.array(Y_test)
AI1_Pred = pd.DataFrame()
AI1_Pred["Predicted Values"] = prediction
AI1_Pred["Actual Values"] = Actual
AI1_Pred.head()
